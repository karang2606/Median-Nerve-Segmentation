# %%
from keras.models import Model
from keras.layers import ReLU, Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want

def conv_block(num_filter, in_layer, drop_out):
    
    x = Conv2D(num_filter,  (3, 3), kernel_initializer=kernel_initializer, padding='same')(in_layer)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)
    x = Dropout(drop_out)(x)
    x = Conv2D(num_filter,  (3, 3), kernel_initializer=kernel_initializer, padding='same')(x)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)
    return x

def upConv_block(num_filter, in_layer, concate_list, drop_out):
    
    x = Conv2DTranspose(num_filter, (2, 2), strides=(2, 2), padding='same')(in_layer)
    x = concatenate([x]+concate_list)
    x = ReLU()(x)    
    x = Conv2D(num_filter,  (3, 3), kernel_initializer=kernel_initializer, padding='same')(x)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)    
    x = Dropout(drop_out)(x)
    x = Conv2D(num_filter,  (3, 3), kernel_initializer=kernel_initializer, padding='same')(x)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)
    return x
    
################################################################
def unet_pp(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, num_classes):
#Build the model
    num_filter = 16
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    x00 = conv_block(num_filter, s, 0.1)
    p1 = MaxPooling2D((2, 2))(x00)
    
    x10 = conv_block(2*num_filter, p1, 0.1)   
    p2 = MaxPooling2D((2, 2))(x10)

    x01 = upConv_block(num_filter, x10, [x00], 0.2)

    x20 = conv_block(4*num_filter, p2, 0.2)   
    p3 = MaxPooling2D((2, 2))(x20)
    
    x11 = upConv_block(2*num_filter, x20, [x10], 0.2)

    x02 = upConv_block(num_filter, x11, [x01, x00], 0.2)

    x30 = conv_block(4*num_filter, p3, 0.2)   
    p4 = MaxPooling2D(pool_size=(2, 2))(x30)
    
    x21 = upConv_block(4*num_filter, x30, [x20], 0.2)
        
    x12 = upConv_block(4*num_filter, x21, [x11, x10], 0.2)
    
    x03 = upConv_block(num_filter, x12, [x02, x01,  x00], 0.2)
    
    x40 = conv_block(16*num_filter, p4, 0.3)   

    #Expansive path 
    x31 = upConv_block(8*num_filter, x40, [x30], 0.2)
 
    x22 = upConv_block(4*num_filter, x31, [x21, x20], 0.2)
    
    x13 = upConv_block(2*num_filter, x22, [x12, x11, x10], 0.1)
     
    x04 = upConv_block(num_filter, x13, [x03, x02, x01, x00], 0.1)

    outputs = Conv2D(num_classes, (1, 1), activation='sigmoid')(x04)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible. 
    
    return model

def main():
    #Test if everything is working ok. 
    model = unet_pp(IMG_HEIGHT=448, 
                    IMG_WIDTH=336, 
                    IMG_CHANNELS=1, 
                    num_classes=1)


    print(model.input_shape)
    print(model.output_shape)
    model.summary()
    
if __name__=="__main__":
    main()
# Out:
# 2023-01-16 22:33:20.772684: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-16 22:33:21.846162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 822 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:17:00.0, compute capability: 8.6
# 2023-01-16 22:33:21.846705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 39704 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:65:00.0, compute capability: 8.6
# (None, 448, 336, 1)
# (None, 448, 336, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 448, 336, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 448, 336, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 448, 336, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 448, 336, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 448, 336, 16  0           ['re_lu[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 448, 336, 16  2320        ['dropout[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 448, 336, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 448, 336, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 224, 168, 16  0           ['re_lu_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 168, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 224, 168, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 224, 168, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 224, 168, 32  0           ['re_lu_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 168, 32  9248        ['dropout_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 224, 168, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  re_lu_3 (ReLU)                 (None, 224, 168, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 112, 84, 32)  0          ['re_lu_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 112, 84, 64)  18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 112, 84, 64)  256        ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 112, 84, 64)  0           ['batch_normalization_6[0][0]']
#
#  dropout_3 (Dropout)            (None, 112, 84, 64)  0           ['re_lu_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 112, 84, 64)  36928       ['dropout_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 112, 84, 64)  256        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 112, 84, 64)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 42, 64)  0           ['re_lu_8[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 42, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 42, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 56, 42, 64)   0           ['batch_normalization_12[0][0]']
#
#  dropout_6 (Dropout)            (None, 56, 42, 64)   0           ['re_lu_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 42, 64)   36928       ['dropout_6[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 42, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 56, 42, 64)   0           ['batch_normalization_13[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 21, 64)  0           ['re_lu_16[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 21, 256)  147712      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 21, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 28, 21, 256)  0           ['batch_normalization_20[0][0]']
#
#  dropout_10 (Dropout)           (None, 28, 21, 256)  0           ['re_lu_26[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 21, 256)  590080      ['dropout_10[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 21, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 28, 21, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 56, 42, 128)  131200     ['re_lu_27[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 56, 42, 192)  0           ['conv2d_transpose_6[0][0]',
#                                                                   're_lu_16[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 84, 64)  16448      ['re_lu_16[0][0]']
#  spose)
#
#  re_lu_28 (ReLU)                (None, 56, 42, 192)  0           ['concatenate_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 112, 84, 128  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 're_lu_8[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 224, 168, 32  8224       ['re_lu_8[0][0]']
#  spose)                         )
#
#  conv2d_22 (Conv2D)             (None, 56, 42, 128)  221312      ['re_lu_28[0][0]']
#
#  re_lu_17 (ReLU)                (None, 112, 84, 128  0           ['concatenate_3[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 224, 168, 64  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 're_lu_3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 448, 336, 16  2064       ['re_lu_3[0][0]']
#  ose)                           )
#
#  batch_normalization_22 (BatchN  (None, 56, 42, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 112, 84, 64)  73792       ['re_lu_17[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 224, 168, 64  0           ['concatenate_1[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 448, 336, 32  0           ['conv2d_transpose[0][0]',
#                                 )                                 're_lu_1[0][0]']
#
#  re_lu_29 (ReLU)                (None, 56, 42, 128)  0           ['batch_normalization_22[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 112, 84, 64)  256        ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)              (None, 224, 168, 32  18464       ['re_lu_9[0][0]']
#                                 )
#
#  re_lu_4 (ReLU)                 (None, 448, 336, 32  0           ['concatenate[0][0]']
#                                 )
#
#  dropout_11 (Dropout)           (None, 56, 42, 128)  0           ['re_lu_29[0][0]']
#
#  re_lu_18 (ReLU)                (None, 112, 84, 64)  0           ['batch_normalization_14[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 224, 168, 32  128        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  conv2d_4 (Conv2D)              (None, 448, 336, 16  4624        ['re_lu_4[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 56, 42, 128)  147584      ['dropout_11[0][0]']
#
#  dropout_7 (Dropout)            (None, 112, 84, 64)  0           ['re_lu_18[0][0]']
#
#  re_lu_10 (ReLU)                (None, 224, 168, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 448, 336, 16  64         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  batch_normalization_23 (BatchN  (None, 56, 42, 128)  512        ['conv2d_23[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 112, 84, 64)  36928       ['dropout_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 224, 168, 32  0           ['re_lu_10[0][0]']
#                                 )
#
#  re_lu_5 (ReLU)                 (None, 448, 336, 16  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  re_lu_30 (ReLU)                (None, 56, 42, 128)  0           ['batch_normalization_23[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 112, 84, 64)  256        ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)              (None, 224, 168, 32  9248        ['dropout_4[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 448, 336, 16  0           ['re_lu_5[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 112, 84, 64)  32832      ['re_lu_30[0][0]']
#  spose)
#
#  re_lu_19 (ReLU)                (None, 112, 84, 64)  0           ['batch_normalization_15[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 224, 168, 32  128        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  conv2d_5 (Conv2D)              (None, 448, 336, 16  2320        ['dropout_2[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 112, 84, 192  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 're_lu_19[0][0]',
#                                                                   're_lu_8[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 224, 168, 64  16448      ['re_lu_19[0][0]']
#  spose)                         )
#
#  re_lu_11 (ReLU)                (None, 224, 168, 32  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 448, 336, 16  64         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  re_lu_31 (ReLU)                (None, 112, 84, 192  0           ['concatenate_7[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 224, 168, 12  0           ['conv2d_transpose_4[0][0]',
#                                 8)                                're_lu_11[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 448, 336, 16  2064       ['re_lu_11[0][0]']
#  spose)                         )
#
#  re_lu_6 (ReLU)                 (None, 448, 336, 16  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 112, 84, 64)  110656      ['re_lu_31[0][0]']
#
#  re_lu_20 (ReLU)                (None, 224, 168, 12  0           ['concatenate_4[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 448, 336, 48  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 're_lu_6[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 112, 84, 64)  256        ['conv2d_24[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 224, 168, 64  73792       ['re_lu_20[0][0]']
#                                 )
#  re_lu_12 (ReLU)                (None, 448, 336, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  re_lu_32 (ReLU)                (None, 112, 84, 64)  0           ['batch_normalization_24[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 224, 168, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  conv2d_10 (Conv2D)             (None, 448, 336, 16  6928        ['re_lu_12[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 112, 84, 64)  0           ['re_lu_32[0][0]']
#
#  re_lu_21 (ReLU)                (None, 224, 168, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 448, 336, 16  64         ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  conv2d_25 (Conv2D)             (None, 112, 84, 64)  36928       ['dropout_12[0][0]']
#
#  dropout_8 (Dropout)            (None, 224, 168, 64  0           ['re_lu_21[0][0]']
#                                 )
#
#  re_lu_13 (ReLU)                (None, 448, 336, 16  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 112, 84, 64)  256        ['conv2d_25[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (None, 224, 168, 64  36928       ['dropout_8[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 448, 336, 16  0           ['re_lu_13[0][0]']
#                                 )
#
#  re_lu_33 (ReLU)                (None, 112, 84, 64)  0           ['batch_normalization_25[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 224, 168, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_11 (Conv2D)             (None, 448, 336, 16  2320        ['dropout_5[0][0]']
#                                 )
#
#  conv2d_transpose_8 (Conv2DTran  (None, 224, 168, 32  8224       ['re_lu_33[0][0]']
#  spose)                         )
#
#  re_lu_22 (ReLU)                (None, 224, 168, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 448, 336, 16  64         ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  concatenate_8 (Concatenate)    (None, 224, 168, 16  0           ['conv2d_transpose_8[0][0]',
#                                 0)                                're_lu_22[0][0]',
#                                                                   're_lu_11[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 448, 336, 16  4112       ['re_lu_22[0][0]']
#  spose)                         )
#
#  re_lu_14 (ReLU)                (None, 448, 336, 16  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  re_lu_34 (ReLU)                (None, 224, 168, 16  0           ['concatenate_8[0][0]']
#                                 0)
#
#  concatenate_5 (Concatenate)    (None, 448, 336, 64  0           ['conv2d_transpose_5[0][0]',
#                                 )                                 're_lu_14[0][0]',
#                                                                   're_lu_6[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 224, 168, 32  46112       ['re_lu_34[0][0]']
#                                 )
#
#  re_lu_23 (ReLU)                (None, 448, 336, 64  0           ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 224, 168, 32  128        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 448, 336, 16  9232        ['re_lu_23[0][0]']
#                                 )
#
#  re_lu_35 (ReLU)                (None, 224, 168, 32  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 448, 336, 16  64         ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  dropout_13 (Dropout)           (None, 224, 168, 32  0           ['re_lu_35[0][0]']
#                                 )
#
#  re_lu_24 (ReLU)                (None, 448, 336, 16  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 224, 168, 32  9248        ['dropout_13[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 448, 336, 16  0           ['re_lu_24[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 224, 168, 32  128        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  conv2d_19 (Conv2D)             (None, 448, 336, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  re_lu_36 (ReLU)                (None, 224, 168, 32  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 448, 336, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_9 (Conv2DTran  (None, 448, 336, 16  2064       ['re_lu_36[0][0]']
#  spose)                         )
#
#  re_lu_25 (ReLU)                (None, 448, 336, 16  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 448, 336, 80  0           ['conv2d_transpose_9[0][0]',
#                                 )                                 're_lu_25[0][0]',
#                                                                   're_lu_14[0][0]',
#                                                                   're_lu_6[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  re_lu_37 (ReLU)                (None, 448, 336, 80  0           ['concatenate_9[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 448, 336, 16  11536       ['re_lu_37[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 448, 336, 16  64         ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  re_lu_38 (ReLU)                (None, 448, 336, 16  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  dropout_14 (Dropout)           (None, 448, 336, 16  0           ['re_lu_38[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 448, 336, 16  2320        ['dropout_14[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 448, 336, 16  64         ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  re_lu_39 (ReLU)                (None, 448, 336, 16  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 448, 336, 1)  17          ['re_lu_39[0][0]']
#
# ==================================================================================================
# Total params: 1,976,769
# Trainable params: 1,973,249
# Non-trainable params: 3,520
# __________________________________________________________________________________________________
