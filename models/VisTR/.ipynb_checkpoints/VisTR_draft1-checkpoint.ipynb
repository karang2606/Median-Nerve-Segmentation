# %%
from parts import *
# Out:
# /home/karan/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from parts import *
#
# File ~/Downloads/VisTR-master/parts.py:30
#      28 from models.vistr import VisTR
#      29 from pycocotools import mask as coco_mask
# ---> 30 import datasets.transforms as T
#      33 def get_args_parser():
#      34     parser = argparse.ArgumentParser('Set transformer detector', add_help=False)
#
# File ~/Downloads/VisTR-master/datasets/__init__.py:5
#       2 import torchvision
#       4 from .coco import build as build_coco
# ----> 5 from .ytvos import build as build_ytvos
#       7 def get_coco_api_from_dataset(dataset):
#       8     for _ in range(10):
#       9         # if isinstance(dataset, torchvision.datasets.CocoDetection):
#      10         #     break
#
# File ~/Downloads/VisTR-master/datasets/ytvos.py:9
#       7 import torch.utils.data
#       8 import torchvision
# ----> 9 from pycocotools.ytvos import YTVOS
#      10 from pycocotools.ytvoseval import YTVOSeval
#      11 import datasets.transforms as T
#
# ModuleNotFoundError: No module named 'pycocotools.ytvos'

# %%
import argparse
import datetime
import json
import random
import time
from pathlib import Path
import numpy as np
import torch
from torch.utils.data import Dataset,DataLoader, DistributedSampler

import datasets
import util.misc as utils
from datasets import build_dataset, get_coco_api_from_dataset
from engine import evaluate, train_one_epoch
from models import build_model
# import torch.nn.functional as F
import matplotlib.pyplot as plt
from models.segmentation import VisTRsegm
import pycocotools.mask as mask_util
from util.box_ops import box_xyxy_to_cxcywh
##
import glob
import re
import os
from torchvision.ops import masks_to_boxes
from PIL import Image
from tqdm.notebook import tqdm
import torchvision.transforms.functional as F
from engine import train_one_epoch

# %%
pat=re.compile("(\d+)\D*$")

def key_func(x):
    mat=pat.search(os.path.split(x)[-1]) # match last group of digits
    if mat is None:
        return x
    return "{:>10}".format(mat.group(1)) # right align to 10 digits

# train_file_dir = glob.glob('./aster_updated_data_22_01_2022/Train/*')
train_file_dir = glob.glob('../Dissertation/aster_updated_data_22_01_2022/Train/*')

n_frames = 36

train_image_list = []
train_mask_list = []

for path in train_file_dir:
    frames = sorted(glob.glob(path+'/*_0001_IMAGES/images/*.jpg'), key=key_func)
    masks = sorted(glob.glob(path+'/*_0001_IMAGES/masks/*.png'), key=key_func)

#     for i in range(35):
    for i in range(len(frames)-n_frames+1):
        train_image_list.append(frames[i:i+n_frames])
        train_mask_list.append(masks[i:i+n_frames])
#         train_mask_list.append(masks[i+n_frames-1])
        
test_file_dir = glob.glob('../Dissertation/aster_updated_data_22_01_2022/Test/*')
test_image_list = []
test_mask_list = []

for path in test_file_dir:
    frames = sorted(glob.glob(path+'/*_0001_IMAGES/images/*.jpg'), key=key_func)
    masks = sorted(glob.glob(path+'/*_0001_IMAGES/masks/*.png'), key=key_func)

#     for i in range(35):
    for i in range(len(frames)-n_frames+1):
        test_image_list.append(frames[i:i+n_frames])
        test_mask_list.append(masks[i:i+n_frames])
#         test_mask_list.append(masks[i+n_frames-1])

# %%
def make_transform(image_set):
    normalize = T.Compose([
        T.ToTensor(),
        T.Normalize([0.2316], [0.2038]) #mean #standard deviation
    ])
    if image_set == 'train':
        return T.Compose([
            T.RandomHorizontalFlip(),
            normalize,
        ])

    if image_set == 'val':
        return T.Compose([normalize])

# %%
def get_bbox(mask_list):
    return torch.cat([masks_to_boxes(mask) for mask in mask_list], dim=0)

# %%
class ImagePathDataset(Dataset):
    def __init__(self, image_path, mask_path, n_frames, transform=None):
        self.image_path = image_path
        self.mask_path = mask_path
        self.n_frames = n_frames
        self.transform = transform
        

    def __len__(self):
        return len(self.image_path)

    def __getitem__(self, idx):
        
        image = [Image.open(self.image_path[idx][i]) for i in range(self.n_frames)]
        mask = [F.to_tensor(Image.open(self.mask_path[idx][i]))
                for i in range(self.n_frames)]
        
        target = {}
        target['labels'] = torch.ones(36).long()
        target['valid'] = torch.ones(36).long()
        target['masks'] = torch.cat(mask, dim=0)
        target['boxes'] = get_bbox(mask)
        
        if self.transform is not None:
            image, target = self.transform(image, target)
        
        image = [img.repeat(3,1,1) for img in image]
            
        return torch.cat(image,dim=0), target

# %%
parser = argparse.ArgumentParser('VisTR training and evaluation script',
                                 parents=[get_args_parser()])
args = parser.parse_args("")
args
if args.output_dir:
    Path(args.output_dir).mkdir(parents=True, exist_ok=True)

args.pretrained_weights = 'pretrained/r101.pth'
args.masks = True

args.device = 'cuda:1'

# %%
# import torch
# import torch.utils.data
# import torchvision
# from pycocotools.ytvos import YTVOS
# from pycocotools.ytvoseval import YTVOSeval
# import datasets.transforms as T
# from pycocotools import mask as coco_mask
# import os
# from PIL import Image
# from random import randint
# import cv2
# import random

# %%
utils.init_distributed_mode(args)
# print("git:\n  {}\n".format(utils.get_sha()))
device = torch.device(args.device)

# fix the seed for reproducibility
seed = args.seed + utils.get_rank()
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

model, criterion, postprocessors = build_model(args)
model.to(device)

model_without_ddp = model
if args.distributed:
    model = torch.nn.parallel.DistributedDataParallel(model, device_ids=[args.gpu])
    model_without_ddp = model.module
n_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('number of params:', n_parameters)

param_dicts = [
    {"params": [p for n, p in model_without_ddp.named_parameters() if "backbone" not in n and p.requires_grad]},
    {
        "params": [p for n, p in model_without_ddp.named_parameters() if "backbone" in n and p.requires_grad],
        "lr": args.lr_backbone,
    },
]
optimizer = torch.optim.AdamW(param_dicts, lr=args.lr,
                              weight_decay=args.weight_decay)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, args.lr_drop)
# Out:
# Not using distributed mode
# /home/karan/anaconda3/envs/tr/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/karan/anaconda3/envs/tr/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 75833633

# %%
# no validation ground truth for ytvos dataset
dataset_train = ImagePathDataset(train_image_list, train_mask_list,
                                 n_frames, transform=make_transform(image_set='train'))
if args.distributed:
    sampler_train = DistributedSampler(dataset_train)
else:
    sampler_train = torch.utils.data.RandomSampler(dataset_train)

batch_sampler_train = torch.utils.data.BatchSampler(
    sampler_train, args.batch_size, drop_last=True)

data_loader_train = DataLoader(dataset_train, batch_sampler=batch_sampler_train,
                               collate_fn=utils.collate_fn, num_workers=args.num_workers)

output_dir = Path(args.output_dir)

# %%
print("Start training")
start_time = time.time()
for epoch in range(args.start_epoch, args.epochs):
    if args.distributed:
        sampler_train.set_epoch(epoch)
    train_stats = train_one_epoch(
        model, criterion, data_loader_train, optimizer, device, epoch,
        args.clip_max_norm)
    lr_scheduler.step()
    if args.output_dir:
        checkpoint_paths = [output_dir / 'checkpoint.pth']
        # extra checkpoint before LR drop and every epochs
        if (epoch + 1) % args.lr_drop == 0 or (epoch + 1) % 1 == 0:
            checkpoint_paths.append(output_dir / f'checkpoint{epoch:04}.pth')
        for checkpoint_path in checkpoint_paths:
            utils.save_on_master({
                'model': model_without_ddp.state_dict(),
                'optimizer': optimizer.state_dict(),
                'lr_scheduler': lr_scheduler.state_dict(),
                'epoch': epoch,
                'args': args,
            }, checkpoint_path)
# Out:
# Start training
# Epoch: [0]  [    0/23329]  eta: 22:22:44  lr: 0.000100  class_error: 75.00  loss: 62.8469 (62.8469)  loss_ce: 3.3563 (3.3563)  loss_bbox: 4.6083 (4.6083)  loss_giou: 1.8827 (1.8827)  loss_mask: 0.0394 (0.0394)  loss_dice: 0.9730 (0.9730)  loss_ce_0: 4.1464 (4.1464)  loss_bbox_0: 4.4311 (4.4311)  loss_giou_0: 1.8450 (1.8450)  loss_ce_1: 4.1611 (4.1611)  loss_bbox_1: 4.4696 (4.4696)  loss_giou_1: 1.8452 (1.8452)  loss_ce_2: 4.1558 (4.1558)  loss_bbox_2: 4.3878 (4.3878)  loss_giou_2: 1.8364 (1.8364)  loss_ce_3: 3.9694 (3.9694)  loss_bbox_3: 4.3635 (4.3635)  loss_giou_3: 1.8478 (1.8478)  loss_ce_4: 3.9817 (3.9817)  loss_bbox_4: 4.6663 (4.6663)  loss_giou_4: 1.8803 (1.8803)  loss_ce_unscaled: 3.3563 (3.3563)  class_error_unscaled: 75.0000 (75.0000)  loss_bbox_unscaled: 0.9217 (0.9217)  loss_giou_unscaled: 0.9413 (0.9413)  cardinality_error_unscaled: 324.0000 (324.0000)  loss_mask_unscaled: 0.0394 (0.0394)  loss_dice_unscaled: 0.9730 (0.9730)  loss_ce_0_unscaled: 4.1464 (4.1464)  loss_bbox_0_unscaled: 0.8862 (0.8862)  loss_giou_0_unscaled: 0.9225 (0.9225)  cardinality_error_0_unscaled: 324.0000 (324.0000)  loss_ce_1_unscaled: 4.1611 (4.1611)  loss_bbox_1_unscaled: 0.8939 (0.8939)  loss_giou_1_unscaled: 0.9226 (0.9226)  cardinality_error_1_unscaled: 324.0000 (324.0000)  loss_ce_2_unscaled: 4.1558 (4.1558)  loss_bbox_2_unscaled: 0.8776 (0.8776)  loss_giou_2_unscaled: 0.9182 (0.9182)  cardinality_error_2_unscaled: 324.0000 (324.0000)  loss_ce_3_unscaled: 3.9694 (3.9694)  loss_bbox_3_unscaled: 0.8727 (0.8727)  loss_giou_3_unscaled: 0.9239 (0.9239)  cardinality_error_3_unscaled: 324.0000 (324.0000)  loss_ce_4_unscaled: 3.9817 (3.9817)  loss_bbox_4_unscaled: 0.9333 (0.9333)  loss_giou_4_unscaled: 0.9402 (0.9402)  cardinality_error_4_unscaled: 324.0000 (324.0000)  time: 3.4534  data: 0.4923  max mem: 0
# Epoch: [0]  [   10/23329]  eta: 11:12:11  lr: 0.000100  class_error: 36.11  loss: 42.7600 (42.8114)  loss_ce: 0.8609 (1.2373)  loss_bbox: 3.5496 (3.4493)  loss_giou: 2.1191 (2.2477)  loss_mask: 0.0289 (0.0300)  loss_dice: 0.9730 (0.9739)  loss_ce_0: 0.8881 (1.3092)  loss_bbox_0: 3.6687 (3.5676)  loss_giou_0: 2.0540 (2.2003)  loss_ce_1: 0.9132 (1.3446)  loss_bbox_1: 3.3100 (3.3472)  loss_giou_1: 2.1317 (2.2531)  loss_ce_2: 0.8908 (1.3589)  loss_bbox_2: 3.3205 (3.3612)  loss_giou_2: 2.1358 (2.2478)  loss_ce_3: 0.9201 (1.3200)  loss_bbox_3: 3.3121 (3.3234)  loss_giou_3: 2.0815 (2.2516)  loss_ce_4: 0.8431 (1.2960)  loss_bbox_4: 3.4057 (3.4386)  loss_giou_4: 2.1250 (2.2537)  loss_ce_unscaled: 0.8609 (1.2373)  class_error_unscaled: 47.2222 (44.6970)  loss_bbox_unscaled: 0.7099 (0.6899)  loss_giou_unscaled: 1.0596 (1.1239)  cardinality_error_unscaled: 141.0000 (167.9091)  loss_mask_unscaled: 0.0289 (0.0300)  loss_dice_unscaled: 0.9730 (0.9739)  loss_ce_0_unscaled: 0.8881 (1.3092)  loss_bbox_0_unscaled: 0.7337 (0.7135)  loss_giou_0_unscaled: 1.0270 (1.1002)  cardinality_error_0_unscaled: 230.0000 (215.6364)  loss_ce_1_unscaled: 0.9132 (1.3446)  loss_bbox_1_unscaled: 0.6620 (0.6694)  loss_giou_1_unscaled: 1.0659 (1.1266)  cardinality_error_1_unscaled: 168.0000 (177.6364)  loss_ce_2_unscaled: 0.8908 (1.3589)  loss_bbox_2_unscaled: 0.6641 (0.6722)  loss_giou_2_unscaled: 1.0679 (1.1239)  cardinality_error_2_unscaled: 242.0000 (240.8182)  loss_ce_3_unscaled: 0.9201 (1.3200)  loss_bbox_3_unscaled: 0.6624 (0.6647)  loss_giou_3_unscaled: 1.0408 (1.1258)  cardinality_error_3_unscaled: 209.0000 (202.8182)  loss_ce_4_unscaled: 0.8431 (1.2960)  loss_bbox_4_unscaled: 0.6811 (0.6877)  loss_giou_4_unscaled: 1.0625 (1.1268)  cardinality_error_4_unscaled: 170.0000 (166.4545)  time: 1.7296  data: 0.0562  max mem: 0
# Epoch: [0]  [   20/23329]  eta: 10:41:10  lr: 0.000100  class_error: 19.44  loss: 39.0517 (39.9649)  loss_ce: 0.8444 (1.0393)  loss_bbox: 2.6686 (2.9269)  loss_giou: 2.5197 (2.5219)  loss_mask: 0.0266 (0.0277)  loss_dice: 0.9742 (0.9752)  loss_ce_0: 0.8340 (1.0742)  loss_bbox_0: 2.8516 (3.0114)  loss_giou_0: 2.4261 (2.4482)  loss_ce_1: 0.8682 (1.0992)  loss_bbox_1: 2.6223 (2.8624)  loss_giou_1: 2.3572 (2.5108)  loss_ce_2: 0.8756 (1.1113)  loss_bbox_2: 2.6009 (2.8733)  loss_giou_2: 2.4666 (2.5296)  loss_ce_3: 0.8752 (1.0890)  loss_bbox_3: 2.5787 (2.8437)  loss_giou_3: 2.4586 (2.5310)  loss_ce_4: 0.8409 (1.0717)  loss_bbox_4: 2.6467 (2.9074)  loss_giou_4: 2.4555 (2.5107)  loss_ce_unscaled: 0.8444 (1.0393)  class_error_unscaled: 36.1111 (39.2857)  loss_bbox_unscaled: 0.5337 (0.5854)  loss_giou_unscaled: 1.2599 (1.2609)  cardinality_error_unscaled: 148.0000 (171.7143)  loss_mask_unscaled: 0.0266 (0.0277)  loss_dice_unscaled: 0.9742 (0.9752)  loss_ce_0_unscaled: 0.8340 (1.0742)  loss_bbox_0_unscaled: 0.5703 (0.6023)  loss_giou_0_unscaled: 1.2131 (1.2241)  cardinality_error_0_unscaled: 182.0000 (207.1429)  loss_ce_1_unscaled: 0.8682 (1.0992)  loss_bbox_1_unscaled: 0.5245 (0.5725)  loss_giou_1_unscaled: 1.1786 (1.2554)  cardinality_error_1_unscaled: 180.0000 (186.8095)  loss_ce_2_unscaled: 0.8756 (1.1113)  loss_bbox_2_unscaled: 0.5202 (0.5747)  loss_giou_2_unscaled: 1.2333 (1.2648)  cardinality_error_2_unscaled: 207.0000 (213.5238)  loss_ce_3_unscaled: 0.8752 (1.0890)  loss_bbox_3_unscaled: 0.5157 (0.5687)  loss_giou_3_unscaled: 1.2293 (1.2655)  cardinality_error_3_unscaled: 209.0000 (205.7619)  loss_ce_4_unscaled: 0.8409 (1.0717)  loss_bbox_4_unscaled: 0.5293 (0.5815)  loss_giou_4_unscaled: 1.2278 (1.2554)  cardinality_error_4_unscaled: 170.0000 (176.4762)  time: 1.5603  data: 0.0137  max mem: 0
# Epoch: [0]  [   30/23329]  eta: 10:21:26  lr: 0.000100  class_error: 8.33  loss: 32.0547 (36.8618)  loss_ce: 0.7463 (0.9402)  loss_bbox: 1.7890 (2.4889)  loss_giou: 2.8381 (2.5486)  loss_mask: 0.0236 (0.0263)  loss_dice: 0.9744 (0.9742)  loss_ce_0: 0.7696 (0.9697)  loss_bbox_0: 1.7823 (2.5382)  loss_giou_0: 2.7707 (2.4824)  loss_ce_1: 0.7651 (0.9840)  loss_bbox_1: 1.6771 (2.4368)  loss_giou_1: 2.7871 (2.5320)  loss_ce_2: 0.7756 (0.9930)  loss_bbox_2: 1.7385 (2.4459)  loss_giou_2: 2.8479 (2.5495)  loss_ce_3: 0.7699 (0.9799)  loss_bbox_3: 1.6682 (2.4282)  loss_giou_3: 2.8587 (2.5568)  loss_ce_4: 0.7619 (0.9650)  loss_bbox_4: 1.7576 (2.4815)  loss_giou_4: 2.8355 (2.5409)  loss_ce_unscaled: 0.7463 (0.9402)  class_error_unscaled: 22.2222 (33.6022)  loss_bbox_unscaled: 0.3578 (0.4978)  loss_giou_unscaled: 1.4191 (1.2743)  cardinality_error_unscaled: 206.0000 (185.6129)  loss_mask_unscaled: 0.0236 (0.0263)  loss_dice_unscaled: 0.9744 (0.9742)  loss_ce_0_unscaled: 0.7696 (0.9697)  loss_bbox_0_unscaled: 0.3565 (0.5076)  loss_giou_0_unscaled: 1.3854 (1.2412)  cardinality_error_0_unscaled: 179.0000 (198.3548)  loss_ce_1_unscaled: 0.7651 (0.9840)  loss_bbox_1_unscaled: 0.3354 (0.4874)  loss_giou_1_unscaled: 1.3936 (1.2660)  cardinality_error_1_unscaled: 202.0000 (194.3871)  loss_ce_2_unscaled: 0.7756 (0.9930)  loss_bbox_2_unscaled: 0.3477 (0.4892)  loss_giou_2_unscaled: 1.4240 (1.2747)  cardinality_error_2_unscaled: 189.0000 (209.7742)  loss_ce_3_unscaled: 0.7699 (0.9799)  loss_bbox_3_unscaled: 0.3336 (0.4856)  loss_giou_3_unscaled: 1.4294 (1.2784)  cardinality_error_3_unscaled: 199.0000 (189.7097)  loss_ce_4_unscaled: 0.7619 (0.9650)  loss_bbox_4_unscaled: 0.3515 (0.4963)  loss_giou_4_unscaled: 1.4177 (1.2705)  cardinality_error_4_unscaled: 192.0000 (185.4839)  time: 1.5293  data: 0.0145  max mem: 0
# Epoch: [0]  [   40/23329]  eta: 10:16:04  lr: 0.000100  class_error: 5.56  loss: 31.9428 (35.9027)  loss_ce: 0.7193 (0.8848)  loss_bbox: 1.5113 (2.2895)  loss_giou: 2.9033 (2.6409)  loss_mask: 0.0227 (0.0253)  loss_dice: 0.9729 (0.9735)  loss_ce_0: 0.7356 (0.9113)  loss_bbox_0: 1.5233 (2.3349)  loss_giou_0: 2.9040 (2.5885)  loss_ce_1: 0.7262 (0.9201)  loss_bbox_1: 1.5477 (2.2576)  loss_giou_1: 2.8983 (2.6258)  loss_ce_2: 0.7272 (0.9268)  loss_bbox_2: 1.5020 (2.2641)  loss_giou_2: 2.8981 (2.6354)  loss_ce_3: 0.7356 (0.9173)  loss_bbox_3: 1.5554 (2.2452)  loss_giou_3: 2.9157 (2.6437)  loss_ce_4: 0.7271 (0.9046)  loss_bbox_4: 1.5238 (2.2816)  loss_giou_4: 2.8872 (2.6318)  loss_ce_unscaled: 0.7193 (0.8848)  class_error_unscaled: 22.2222 (31.6396)  loss_bbox_unscaled: 0.3023 (0.4579)  loss_giou_unscaled: 1.4516 (1.3204)  cardinality_error_unscaled: 208.0000 (189.1951)  loss_mask_unscaled: 0.0227 (0.0253)  loss_dice_unscaled: 0.9729 (0.9735)  loss_ce_0_unscaled: 0.7356 (0.9113)  loss_bbox_0_unscaled: 0.3047 (0.4670)  loss_giou_0_unscaled: 1.4520 (1.2943)  cardinality_error_0_unscaled: 201.0000 (200.1463)  loss_ce_1_unscaled: 0.7262 (0.9201)  loss_bbox_1_unscaled: 0.3095 (0.4515)  loss_giou_1_unscaled: 1.4491 (1.3129)  cardinality_error_1_unscaled: 212.0000 (196.4390)  loss_ce_2_unscaled: 0.7272 (0.9268)  loss_bbox_2_unscaled: 0.3004 (0.4528)  loss_giou_2_unscaled: 1.4490 (1.3177)  cardinality_error_2_unscaled: 186.0000 (201.7561)  loss_ce_3_unscaled: 0.7356 (0.9173)  loss_bbox_3_unscaled: 0.3111 (0.4490)  loss_giou_3_unscaled: 1.4579 (1.3219)  cardinality_error_3_unscaled: 192.0000 (201.3902)  loss_ce_4_unscaled: 0.7271 (0.9046)  loss_bbox_4_unscaled: 0.3048 (0.4563)  loss_giou_4_unscaled: 1.4436 (1.3159)  cardinality_error_4_unscaled: 204.0000 (192.6341)  time: 1.5207  data: 0.0145  max mem: 0
# Epoch: [0]  [   50/23329]  eta: 10:03:45  lr: 0.000100  class_error: 36.11  loss: 31.7170 (34.9614)  loss_ce: 0.7038 (0.8483)  loss_bbox: 1.4199 (2.1547)  loss_giou: 2.8496 (2.6516)  loss_mask: 0.0222 (0.0246)  loss_dice: 0.9710 (0.9734)  loss_ce_0: 0.7186 (0.8723)  loss_bbox_0: 1.4346 (2.1886)  loss_giou_0: 2.8622 (2.6152)  loss_ce_1: 0.7129 (0.8778)  loss_bbox_1: 1.5477 (2.1356)  loss_giou_1: 2.9342 (2.6447)  loss_ce_2: 0.7122 (0.8830)  loss_bbox_2: 1.5020 (2.1375)  loss_giou_2: 2.8897 (2.6525)  loss_ce_3: 0.7123 (0.8753)  loss_bbox_3: 1.4164 (2.1172)  loss_giou_3: 2.8557 (2.6545)  loss_ce_4: 0.7088 (0.8651)  loss_bbox_4: 1.3986 (2.1458)  loss_giou_4: 2.8632 (2.6437)  loss_ce_unscaled: 0.7038 (0.8483)  class_error_unscaled: 30.5556 (31.2092)  loss_bbox_unscaled: 0.2840 (0.4309)  loss_giou_unscaled: 1.4248 (1.3258)  cardinality_error_unscaled: 180.0000 (189.3922)  loss_mask_unscaled: 0.0222 (0.0246)  loss_dice_unscaled: 0.9710 (0.9734)  loss_ce_0_unscaled: 0.7186 (0.8723)  loss_bbox_0_unscaled: 0.2869 (0.4377)  loss_giou_0_unscaled: 1.4311 (1.3076)  cardinality_error_0_unscaled: 208.0000 (199.2353)  loss_ce_1_unscaled: 0.7129 (0.8778)  loss_bbox_1_unscaled: 0.3095 (0.4271)  loss_giou_1_unscaled: 1.4671 (1.3223)  cardinality_error_1_unscaled: 203.0000 (199.1569)  loss_ce_2_unscaled: 0.7122 (0.8830)  loss_bbox_2_unscaled: 0.3004 (0.4275)  loss_giou_2_unscaled: 1.4448 (1.3262)  cardinality_error_2_unscaled: 221.0000 (208.4706)  loss_ce_3_unscaled: 0.7123 (0.8753)  loss_bbox_3_unscaled: 0.2833 (0.4234)  loss_giou_3_unscaled: 1.4278 (1.3273)  cardinality_error_3_unscaled: 180.0000 (193.1961)  loss_ce_4_unscaled: 0.7088 (0.8651)  loss_bbox_4_unscaled: 0.2797 (0.4292)  loss_giou_4_unscaled: 1.4316 (1.3218)  cardinality_error_4_unscaled: 203.0000 (196.3922)  time: 1.4877  data: 0.0146  max mem: 0
# Epoch: [0]  [   60/23329]  eta: 9:51:08  lr: 0.000100  class_error: 30.56  loss: 32.0666 (34.9089)  loss_ce: 0.6990 (0.8233)  loss_bbox: 1.6954 (2.1085)  loss_giou: 2.9057 (2.7111)  loss_mask: 0.0218 (0.0242)  loss_dice: 0.9694 (0.9725)  loss_ce_0: 0.7064 (0.8440)  loss_bbox_0: 1.5582 (2.1373)  loss_giou_0: 2.8802 (2.6815)  loss_ce_1: 0.6997 (0.8482)  loss_bbox_1: 1.5675 (2.0988)  loss_giou_1: 2.9152 (2.7098)  loss_ce_2: 0.6969 (0.8525)  loss_bbox_2: 1.6024 (2.0975)  loss_giou_2: 2.8897 (2.7171)  loss_ce_3: 0.6986 (0.8456)  loss_bbox_3: 1.6897 (2.0777)  loss_giou_3: 2.9016 (2.7160)  loss_ce_4: 0.6992 (0.8377)  loss_bbox_4: 1.7356 (2.1012)  loss_giou_4: 2.8840 (2.7042)  loss_ce_unscaled: 0.6990 (0.8233)  class_error_unscaled: 27.7778 (30.3279)  loss_bbox_unscaled: 0.3391 (0.4217)  loss_giou_unscaled: 1.4529 (1.3555)  cardinality_error_unscaled: 191.0000 (193.1148)  loss_mask_unscaled: 0.0218 (0.0242)  loss_dice_unscaled: 0.9694 (0.9725)  loss_ce_0_unscaled: 0.7064 (0.8440)  loss_bbox_0_unscaled: 0.3116 (0.4275)  loss_giou_0_unscaled: 1.4401 (1.3407)  cardinality_error_0_unscaled: 200.0000 (199.3934)  loss_ce_1_unscaled: 0.6997 (0.8482)  loss_bbox_1_unscaled: 0.3135 (0.4198)  loss_giou_1_unscaled: 1.4576 (1.3549)  cardinality_error_1_unscaled: 208.0000 (200.6885)  loss_ce_2_unscaled: 0.6969 (0.8525)  loss_bbox_2_unscaled: 0.3205 (0.4195)  loss_giou_2_unscaled: 1.4448 (1.3585)  cardinality_error_2_unscaled: 196.0000 (203.4098)  loss_ce_3_unscaled: 0.6986 (0.8456)  loss_bbox_3_unscaled: 0.3379 (0.4155)  loss_giou_3_unscaled: 1.4508 (1.3580)  cardinality_error_3_unscaled: 183.0000 (196.0492)  loss_ce_4_unscaled: 0.6992 (0.8377)  loss_bbox_4_unscaled: 0.3471 (0.4202)  loss_giou_4_unscaled: 1.4420 (1.3521)  cardinality_error_4_unscaled: 211.0000 (197.7869)  time: 1.3954  data: 0.0135  max mem: 0
# Epoch: [0]  [   70/23329]  eta: 9:42:04  lr: 0.000100  class_error: 36.11  loss: 34.5973 (34.3137)  loss_ce: 0.6950 (0.8050)  loss_bbox: 1.8076 (2.0308)  loss_giou: 3.0653 (2.7125)  loss_mask: 0.0213 (0.0238)  loss_dice: 0.9683 (0.9720)  loss_ce_0: 0.6995 (0.8235)  loss_bbox_0: 1.8449 (2.0536)  loss_giou_0: 3.0115 (2.6860)  loss_ce_1: 0.6952 (0.8266)  loss_bbox_1: 1.8124 (2.0200)  loss_giou_1: 2.9763 (2.7077)  loss_ce_2: 0.6943 (0.8302)  loss_bbox_2: 1.7756 (2.0188)  loss_giou_2: 2.9798 (2.7132)  loss_ce_3: 0.6951 (0.8244)  loss_bbox_3: 1.8333 (2.0040)  loss_giou_3: 3.0085 (2.7135)  loss_ce_4: 0.6971 (0.8178)  loss_bbox_4: 1.7849 (2.0256)  loss_giou_4: 3.0541 (2.7044)  loss_ce_unscaled: 0.6950 (0.8050)  class_error_unscaled: 27.7778 (29.6557)  loss_bbox_unscaled: 0.3615 (0.4062)  loss_giou_unscaled: 1.5326 (1.3563)  cardinality_error_unscaled: 205.0000 (194.3803)  loss_mask_unscaled: 0.0213 (0.0238)  loss_dice_unscaled: 0.9683 (0.9720)  loss_ce_0_unscaled: 0.6995 (0.8235)  loss_bbox_0_unscaled: 0.3690 (0.4107)  loss_giou_0_unscaled: 1.5057 (1.3430)  cardinality_error_0_unscaled: 200.0000 (199.8169)  loss_ce_1_unscaled: 0.6952 (0.8266)  loss_bbox_1_unscaled: 0.3625 (0.4040)  loss_giou_1_unscaled: 1.4882 (1.3539)  cardinality_error_1_unscaled: 206.0000 (200.9155)  loss_ce_2_unscaled: 0.6943 (0.8302)  loss_bbox_2_unscaled: 0.3551 (0.4038)  loss_giou_2_unscaled: 1.4899 (1.3566)  cardinality_error_2_unscaled: 200.0000 (206.4225)  loss_ce_3_unscaled: 0.6951 (0.8244)  loss_bbox_3_unscaled: 0.3667 (0.4008)  loss_giou_3_unscaled: 1.5043 (1.3568)  cardinality_error_3_unscaled: 204.0000 (196.8592)  loss_ce_4_unscaled: 0.6971 (0.8178)  loss_bbox_4_unscaled: 0.3570 (0.4051)  loss_giou_4_unscaled: 1.5270 (1.3522)  cardinality_error_4_unscaled: 211.0000 (198.8873)  time: 1.3622  data: 0.0135  max mem: 0
# Epoch: [0]  [   80/23329]  eta: 9:35:34  lr: 0.000100  class_error: 25.00  loss: 30.4603 (33.7874)  loss_ce: 0.6940 (0.7913)  loss_bbox: 1.5108 (1.9669)  loss_giou: 2.7000 (2.7034)  loss_mask: 0.0207 (0.0234)  loss_dice: 0.9673 (0.9712)  loss_ce_0: 0.6960 (0.8074)  loss_bbox_0: 1.5239 (1.9880)  loss_giou_0: 2.7232 (2.6786)  loss_ce_1: 0.6938 (0.8102)  loss_bbox_1: 1.5223 (1.9594)  loss_giou_1: 2.6564 (2.6986)  loss_ce_2: 0.6949 (0.8136)  loss_bbox_2: 1.5559 (1.9582)  loss_giou_2: 2.6296 (2.7017)  loss_ce_3: 0.6933 (0.8080)  loss_bbox_3: 1.5548 (1.9453)  loss_giou_3: 2.6678 (2.7023)  loss_ce_4: 0.6963 (0.8027)  loss_bbox_4: 1.5287 (1.9632)  loss_giou_4: 2.7201 (2.6941)  loss_ce_unscaled: 0.6940 (0.7913)  class_error_unscaled: 22.2222 (29.0809)  loss_bbox_unscaled: 0.3022 (0.3934)  loss_giou_unscaled: 1.3500 (1.3517)  cardinality_error_unscaled: 202.0000 (195.4444)  loss_mask_unscaled: 0.0207 (0.0234)  loss_dice_unscaled: 0.9673 (0.9712)  loss_ce_0_unscaled: 0.6960 (0.8074)  loss_bbox_0_unscaled: 0.3048 (0.3976)  loss_giou_0_unscaled: 1.3616 (1.3393)  cardinality_error_0_unscaled: 201.0000 (200.3580)  loss_ce_1_unscaled: 0.6938 (0.8102)  loss_bbox_1_unscaled: 0.3045 (0.3919)  loss_giou_1_unscaled: 1.3282 (1.3493)  cardinality_error_1_unscaled: 193.0000 (199.4321)  loss_ce_2_unscaled: 0.6949 (0.8136)  loss_bbox_2_unscaled: 0.3112 (0.3916)  loss_giou_2_unscaled: 1.3148 (1.3509)  cardinality_error_2_unscaled: 202.0000 (202.9630)  loss_ce_3_unscaled: 0.6933 (0.8080)  loss_bbox_3_unscaled: 0.3110 (0.3891)  loss_giou_3_unscaled: 1.3339 (1.3511)  cardinality_error_3_unscaled: 202.0000 (197.0000)  loss_ce_4_unscaled: 0.6963 (0.8027)  loss_bbox_4_unscaled: 0.3057 (0.3926)  loss_giou_4_unscaled: 1.3601 (1.3471)  cardinality_error_4_unscaled: 185.0000 (197.5679)  time: 1.3668  data: 0.0146  max mem: 0
# Epoch: [0]  [   90/23329]  eta: 9:30:09  lr: 0.000100  class_error: 22.22  loss: 27.9314 (33.4023)  loss_ce: 0.6932 (0.7805)  loss_bbox: 1.1866 (1.9179)  loss_giou: 2.6239 (2.7012)  loss_mask: 0.0203 (0.0231)  loss_dice: 0.9679 (0.9706)  loss_ce_0: 0.6938 (0.7949)  loss_bbox_0: 1.1554 (1.9341)  loss_giou_0: 2.5718 (2.6763)  loss_ce_1: 0.6937 (0.7974)  loss_bbox_1: 1.1606 (1.9084)  loss_giou_1: 2.5861 (2.6961)  loss_ce_2: 0.6934 (0.8003)  loss_bbox_2: 1.1775 (1.9070)  loss_giou_2: 2.6051 (2.7005)  loss_ce_3: 0.6932 (0.7954)  loss_bbox_3: 1.1806 (1.8973)  loss_giou_3: 2.6380 (2.7011)  loss_ce_4: 0.6928 (0.7905)  loss_bbox_4: 1.1925 (1.9142)  loss_giou_4: 2.6737 (2.6954)  loss_ce_unscaled: 0.6932 (0.7805)  class_error_unscaled: 22.2222 (28.3578)  loss_bbox_unscaled: 0.2373 (0.3836)  loss_giou_unscaled: 1.3119 (1.3506)  cardinality_error_unscaled: 205.0000 (196.7033)  loss_mask_unscaled: 0.0203 (0.0231)  loss_dice_unscaled: 0.9679 (0.9706)  loss_ce_0_unscaled: 0.6938 (0.7949)  loss_bbox_0_unscaled: 0.2311 (0.3868)  loss_giou_0_unscaled: 1.2859 (1.3381)  cardinality_error_0_unscaled: 204.0000 (200.8462)  loss_ce_1_unscaled: 0.6937 (0.7974)  loss_bbox_1_unscaled: 0.2321 (0.3817)  loss_giou_1_unscaled: 1.2930 (1.3481)  cardinality_error_1_unscaled: 189.0000 (200.8901)  loss_ce_2_unscaled: 0.6934 (0.8003)  loss_bbox_2_unscaled: 0.2355 (0.3814)  loss_giou_2_unscaled: 1.3026 (1.3503)  cardinality_error_2_unscaled: 193.0000 (203.4725)  loss_ce_3_unscaled: 0.6932 (0.7954)  loss_bbox_3_unscaled: 0.2361 (0.3795)  loss_giou_3_unscaled: 1.3190 (1.3505)  cardinality_error_3_unscaled: 192.0000 (196.0330)  loss_ce_4_unscaled: 0.6928 (0.7905)  loss_bbox_4_unscaled: 0.2385 (0.3828)  loss_giou_4_unscaled: 1.3369 (1.3477)  cardinality_error_4_unscaled: 186.0000 (199.6923)  time: 1.3675  data: 0.0150  max mem: 0
# Epoch: [0]  [  100/23329]  eta: 9:25:43  lr: 0.000100  class_error: 25.00  loss: 27.1556 (33.2766)  loss_ce: 0.6923 (0.7718)  loss_bbox: 1.1649 (1.8959)  loss_giou: 2.6239 (2.7107)  loss_mask: 0.0203 (0.0229)  loss_dice: 0.9683 (0.9702)  loss_ce_0: 0.6920 (0.7846)  loss_bbox_0: 1.1554 (1.9102)  loss_giou_0: 2.5699 (2.6912)  loss_ce_1: 0.6938 (0.7871)  loss_bbox_1: 1.1456 (1.8867)  loss_giou_1: 2.6000 (2.7088)  loss_ce_2: 0.6934 (0.7897)  loss_bbox_2: 1.1492 (1.8842)  loss_giou_2: 2.6463 (2.7118)  loss_ce_3: 0.6913 (0.7851)  loss_bbox_3: 1.1679 (1.8767)  loss_giou_3: 2.6417 (2.7117)  loss_ce_4: 0.6936 (0.7811)  loss_bbox_4: 1.1925 (1.8905)  loss_giou_4: 2.6737 (2.7056)  loss_ce_unscaled: 0.6923 (0.7718)  class_error_unscaled: 22.2222 (27.9703)  loss_bbox_unscaled: 0.2330 (0.3792)  loss_giou_unscaled: 1.3119 (1.3554)  cardinality_error_unscaled: 209.0000 (197.7426)  loss_mask_unscaled: 0.0203 (0.0229)  loss_dice_unscaled: 0.9683 (0.9702)  loss_ce_0_unscaled: 0.6920 (0.7846)  loss_bbox_0_unscaled: 0.2311 (0.3820)  loss_giou_0_unscaled: 1.2850 (1.3456)  cardinality_error_0_unscaled: 193.0000 (200.1386)  loss_ce_1_unscaled: 0.6938 (0.7871)  loss_bbox_1_unscaled: 0.2291 (0.3773)  loss_giou_1_unscaled: 1.3000 (1.3544)  cardinality_error_1_unscaled: 210.0000 (200.7921)  loss_ce_2_unscaled: 0.6934 (0.7897)  loss_bbox_2_unscaled: 0.2298 (0.3768)  loss_giou_2_unscaled: 1.3232 (1.3559)  cardinality_error_2_unscaled: 201.0000 (202.4257)  loss_ce_3_unscaled: 0.6913 (0.7851)  loss_bbox_3_unscaled: 0.2336 (0.3753)  loss_giou_3_unscaled: 1.3208 (1.3559)  cardinality_error_3_unscaled: 197.0000 (196.9208)  loss_ce_4_unscaled: 0.6936 (0.7811)  loss_bbox_4_unscaled: 0.2385 (0.3781)  loss_giou_4_unscaled: 1.3369 (1.3528)  cardinality_error_4_unscaled: 197.0000 (198.6535)  time: 1.3635  data: 0.0144  max mem: 0
# Epoch: [0]  [  110/23329]  eta: 9:21:59  lr: 0.000100  class_error: 19.44  loss: 34.0381 (33.4791)  loss_ce: 0.6925 (0.7648)  loss_bbox: 1.7544 (1.8991)  loss_giou: 3.1178 (2.7462)  loss_mask: 0.0203 (0.0227)  loss_dice: 0.9686 (0.9698)  loss_ce_0: 0.6920 (0.7762)  loss_bbox_0: 1.7514 (1.9163)  loss_giou_0: 3.1152 (2.7305)  loss_ce_1: 0.6938 (0.7786)  loss_bbox_1: 1.7366 (1.8939)  loss_giou_1: 3.1240 (2.7463)  loss_ce_2: 0.6911 (0.7808)  loss_bbox_2: 1.7066 (1.8895)  loss_giou_2: 3.1348 (2.7483)  loss_ce_3: 0.6909 (0.7767)  loss_bbox_3: 1.7429 (1.8827)  loss_giou_3: 3.1347 (2.7481)  loss_ce_4: 0.6929 (0.7730)  loss_bbox_4: 1.7381 (1.8939)  loss_giou_4: 3.1161 (2.7418)  loss_ce_unscaled: 0.6925 (0.7648)  class_error_unscaled: 22.2222 (27.5275)  loss_bbox_unscaled: 0.3509 (0.3798)  loss_giou_unscaled: 1.5589 (1.3731)  cardinality_error_unscaled: 209.0000 (199.3514)  loss_mask_unscaled: 0.0203 (0.0227)  loss_dice_unscaled: 0.9686 (0.9698)  loss_ce_0_unscaled: 0.6920 (0.7762)  loss_bbox_0_unscaled: 0.3503 (0.3833)  loss_giou_0_unscaled: 1.5576 (1.3653)  cardinality_error_0_unscaled: 195.0000 (200.1441)  loss_ce_1_unscaled: 0.6938 (0.7786)  loss_bbox_1_unscaled: 0.3473 (0.3788)  loss_giou_1_unscaled: 1.5620 (1.3731)  cardinality_error_1_unscaled: 210.0000 (202.1261)  loss_ce_2_unscaled: 0.6911 (0.7808)  loss_bbox_2_unscaled: 0.3413 (0.3779)  loss_giou_2_unscaled: 1.5674 (1.3741)  cardinality_error_2_unscaled: 200.0000 (202.9730)  loss_ce_3_unscaled: 0.6909 (0.7767)  loss_bbox_3_unscaled: 0.3486 (0.3765)  loss_giou_3_unscaled: 1.5674 (1.3740)  cardinality_error_3_unscaled: 197.0000 (196.5586)  loss_ce_4_unscaled: 0.6929 (0.7730)  loss_bbox_4_unscaled: 0.3476 (0.3788)  loss_giou_4_unscaled: 1.5581 (1.3709)  cardinality_error_4_unscaled: 199.0000 (200.9369)  time: 1.3620  data: 0.0143  max mem: 0
# Epoch: [0]  [  120/23329]  eta: 9:18:49  lr: 0.000100  class_error: 25.00  loss: 35.6410 (33.7281)  loss_ce: 0.6925 (0.7589)  loss_bbox: 2.0061 (1.9196)  loss_giou: 3.1178 (2.7733)  loss_mask: 0.0202 (0.0225)  loss_dice: 0.9649 (0.9688)  loss_ce_0: 0.6939 (0.7694)  loss_bbox_0: 1.9443 (1.9328)  loss_giou_0: 3.1601 (2.7606)  loss_ce_1: 0.6916 (0.7714)  loss_bbox_1: 1.9285 (1.9137)  loss_giou_1: 3.1513 (2.7750)  loss_ce_2: 0.6909 (0.7735)  loss_bbox_2: 1.9548 (1.9102)  loss_giou_2: 3.1348 (2.7761)  loss_ce_3: 0.6925 (0.7698)  loss_bbox_3: 1.9470 (1.9041)  loss_giou_3: 3.1347 (2.7761)  loss_ce_4: 0.6939 (0.7666)  loss_bbox_4: 1.9748 (1.9155)  loss_giou_4: 3.1161 (2.7703)  loss_ce_unscaled: 0.6925 (0.7589)  class_error_unscaled: 25.0000 (27.4334)  loss_bbox_unscaled: 0.4012 (0.3839)  loss_giou_unscaled: 1.5589 (1.3866)  cardinality_error_unscaled: 208.0000 (199.0165)  loss_mask_unscaled: 0.0202 (0.0225)  loss_dice_unscaled: 0.9649 (0.9688)  loss_ce_0_unscaled: 0.6939 (0.7694)  loss_bbox_0_unscaled: 0.3889 (0.3866)  loss_giou_0_unscaled: 1.5801 (1.3803)  cardinality_error_0_unscaled: 197.0000 (200.3802)  loss_ce_1_unscaled: 0.6916 (0.7714)  loss_bbox_1_unscaled: 0.3857 (0.3827)  loss_giou_1_unscaled: 1.5757 (1.3875)  cardinality_error_1_unscaled: 211.0000 (202.7603)  loss_ce_2_unscaled: 0.6909 (0.7735)  loss_bbox_2_unscaled: 0.3910 (0.3820)  loss_giou_2_unscaled: 1.5674 (1.3880)  cardinality_error_2_unscaled: 198.0000 (202.4876)  loss_ce_3_unscaled: 0.6925 (0.7698)  loss_bbox_3_unscaled: 0.3894 (0.3808)  loss_giou_3_unscaled: 1.5674 (1.3881)  cardinality_error_3_unscaled: 183.0000 (196.4711)  loss_ce_4_unscaled: 0.6939 (0.7666)  loss_bbox_4_unscaled: 0.3950 (0.3831)  loss_giou_4_unscaled: 1.5581 (1.3851)  cardinality_error_4_unscaled: 204.0000 (199.8264)  time: 1.3609  data: 0.0142  max mem: 0
# Epoch: [0]  [  130/23329]  eta: 9:16:07  lr: 0.000100  class_error: 25.00  loss: 37.0343 (33.9373)  loss_ce: 0.6942 (0.7540)  loss_bbox: 2.1807 (1.9383)  loss_giou: 3.1094 (2.7952)  loss_mask: 0.0195 (0.0223)  loss_dice: 0.9612 (0.9685)  loss_ce_0: 0.6936 (0.7635)  loss_bbox_0: 2.1184 (1.9477)  loss_giou_0: 3.1425 (2.7855)  loss_ce_1: 0.6926 (0.7656)  loss_bbox_1: 2.1877 (1.9308)  loss_giou_1: 3.1201 (2.7980)  loss_ce_2: 0.6938 (0.7673)  loss_bbox_2: 2.2093 (1.9290)  loss_giou_2: 3.0974 (2.7983)  loss_ce_3: 0.6940 (0.7641)  loss_bbox_3: 2.2057 (1.9239)  loss_giou_3: 3.1045 (2.7977)  loss_ce_4: 0.6948 (0.7611)  loss_bbox_4: 2.1856 (1.9338)  loss_giou_4: 3.1089 (2.7928)  loss_ce_unscaled: 0.6942 (0.7540)  class_error_unscaled: 25.0000 (27.5233)  loss_bbox_unscaled: 0.4361 (0.3877)  loss_giou_unscaled: 1.5547 (1.3976)  cardinality_error_unscaled: 191.0000 (198.9618)  loss_mask_unscaled: 0.0195 (0.0223)  loss_dice_unscaled: 0.9612 (0.9685)  loss_ce_0_unscaled: 0.6936 (0.7635)  loss_bbox_0_unscaled: 0.4237 (0.3895)  loss_giou_0_unscaled: 1.5712 (1.3927)  cardinality_error_0_unscaled: 197.0000 (200.0687)  loss_ce_1_unscaled: 0.6926 (0.7656)  loss_bbox_1_unscaled: 0.4375 (0.3862)  loss_giou_1_unscaled: 1.5601 (1.3990)  cardinality_error_1_unscaled: 211.0000 (203.3588)  loss_ce_2_unscaled: 0.6938 (0.7673)  loss_bbox_2_unscaled: 0.4419 (0.3858)  loss_giou_2_unscaled: 1.5487 (1.3992)  cardinality_error_2_unscaled: 187.0000 (201.8397)  loss_ce_3_unscaled: 0.6940 (0.7641)  loss_bbox_3_unscaled: 0.4411 (0.3848)  loss_giou_3_unscaled: 1.5522 (1.3989)  cardinality_error_3_unscaled: 207.0000 (197.3053)  loss_ce_4_unscaled: 0.6948 (0.7611)  loss_bbox_4_unscaled: 0.4371 (0.3868)  loss_giou_4_unscaled: 1.5544 (1.3964)  cardinality_error_4_unscaled: 193.0000 (199.7328)  time: 1.3610  data: 0.0142  max mem: 0
# Epoch: [0]  [  140/23329]  eta: 9:13:40  lr: 0.000100  class_error: 30.56  loss: 32.8557 (33.8135)  loss_ce: 0.6957 (0.7500)  loss_bbox: 1.7029 (1.9236)  loss_giou: 2.8863 (2.7936)  loss_mask: 0.0195 (0.0222)  loss_dice: 0.9612 (0.9679)  loss_ce_0: 0.6932 (0.7584)  loss_bbox_0: 1.6865 (1.9308)  loss_giou_0: 2.8880 (2.7833)  loss_ce_1: 0.6948 (0.7605)  loss_bbox_1: 1.7120 (1.9160)  loss_giou_1: 2.9126 (2.7959)  loss_ce_2: 0.6921 (0.7619)  loss_bbox_2: 1.7304 (1.9156)  loss_giou_2: 2.9072 (2.7967)  loss_ce_3: 0.6939 (0.7589)  loss_bbox_3: 1.7434 (1.9114)  loss_giou_3: 2.9084 (2.7963)  loss_ce_4: 0.6946 (0.7564)  loss_bbox_4: 1.7749 (1.9206)  loss_giou_4: 2.9288 (2.7936)  loss_ce_unscaled: 0.6957 (0.7500)  class_error_unscaled: 25.0000 (27.4626)  loss_bbox_unscaled: 0.3406 (0.3847)  loss_giou_unscaled: 1.4432 (1.3968)  cardinality_error_unscaled: 193.0000 (199.5106)  loss_mask_unscaled: 0.0195 (0.0222)  loss_dice_unscaled: 0.9612 (0.9679)  loss_ce_0_unscaled: 0.6932 (0.7584)  loss_bbox_0_unscaled: 0.3373 (0.3862)  loss_giou_0_unscaled: 1.4440 (1.3917)  cardinality_error_0_unscaled: 198.0000 (200.7447)  loss_ce_1_unscaled: 0.6948 (0.7605)  loss_bbox_1_unscaled: 0.3424 (0.3832)  loss_giou_1_unscaled: 1.4563 (1.3979)  cardinality_error_1_unscaled: 211.0000 (204.2482)  loss_ce_2_unscaled: 0.6921 (0.7619)  loss_bbox_2_unscaled: 0.3461 (0.3831)  loss_giou_2_unscaled: 1.4536 (1.3983)  cardinality_error_2_unscaled: 191.0000 (202.7943)  loss_ce_3_unscaled: 0.6939 (0.7589)  loss_bbox_3_unscaled: 0.3487 (0.3823)  loss_giou_3_unscaled: 1.4542 (1.3981)  cardinality_error_3_unscaled: 209.0000 (198.1631)  loss_ce_4_unscaled: 0.6946 (0.7564)  loss_bbox_4_unscaled: 0.3550 (0.3841)  loss_giou_4_unscaled: 1.4644 (1.3968)  cardinality_error_4_unscaled: 197.0000 (200.9433)  time: 1.3593  data: 0.0140  max mem: 0
# Epoch: [0]  [  150/23329]  eta: 9:11:36  lr: 0.000100  class_error: 38.89  loss: 31.0671 (33.7171)  loss_ce: 0.6955 (0.7463)  loss_bbox: 1.6147 (1.9134)  loss_giou: 2.7628 (2.7957)  loss_mask: 0.0193 (0.0219)  loss_dice: 0.9612 (0.9675)  loss_ce_0: 0.6903 (0.7539)  loss_bbox_0: 1.6466 (1.9197)  loss_giou_0: 2.6934 (2.7825)  loss_ce_1: 0.6931 (0.7560)  loss_bbox_1: 1.6015 (1.9055)  loss_giou_1: 2.7170 (2.7945)  loss_ce_2: 0.6910 (0.7571)  loss_bbox_2: 1.6268 (1.9062)  loss_giou_2: 2.7233 (2.7957)  loss_ce_3: 0.6935 (0.7545)  loss_bbox_3: 1.5975 (1.9007)  loss_giou_3: 2.7300 (2.7937)  loss_ce_4: 0.6926 (0.7520)  loss_bbox_4: 1.6249 (1.9081)  loss_giou_4: 2.7787 (2.7921)  loss_ce_unscaled: 0.6955 (0.7463)  class_error_unscaled: 27.7778 (27.7042)  loss_bbox_unscaled: 0.3229 (0.3827)  loss_giou_unscaled: 1.3814 (1.3979)  cardinality_error_unscaled: 199.0000 (198.8278)  loss_mask_unscaled: 0.0193 (0.0219)  loss_dice_unscaled: 0.9612 (0.9675)  loss_ce_0_unscaled: 0.6903 (0.7539)  loss_bbox_0_unscaled: 0.3293 (0.3839)  loss_giou_0_unscaled: 1.3467 (1.3912)  cardinality_error_0_unscaled: 195.0000 (200.0993)  loss_ce_1_unscaled: 0.6931 (0.7560)  loss_bbox_1_unscaled: 0.3203 (0.3811)  loss_giou_1_unscaled: 1.3585 (1.3972)  cardinality_error_1_unscaled: 188.0000 (203.4238)  loss_ce_2_unscaled: 0.6910 (0.7571)  loss_bbox_2_unscaled: 0.3254 (0.3812)  loss_giou_2_unscaled: 1.3617 (1.3979)  cardinality_error_2_unscaled: 198.0000 (202.0861)  loss_ce_3_unscaled: 0.6935 (0.7545)  loss_bbox_3_unscaled: 0.3195 (0.3801)  loss_giou_3_unscaled: 1.3650 (1.3968)  cardinality_error_3_unscaled: 204.0000 (197.8940)  loss_ce_4_unscaled: 0.6926 (0.7520)  loss_bbox_4_unscaled: 0.3250 (0.3816)  loss_giou_4_unscaled: 1.3894 (1.3961)  cardinality_error_4_unscaled: 192.0000 (200.1987)  time: 1.3595  data: 0.0135  max mem: 0
# Epoch: [0]  [  160/23329]  eta: 9:09:39  lr: 0.000100  class_error: 27.78  loss: 31.1908 (33.5694)  loss_ce: 0.6921 (0.7429)  loss_bbox: 1.6147 (1.8910)  loss_giou: 2.8262 (2.7981)  loss_mask: 0.0182 (0.0217)  loss_dice: 0.9637 (0.9672)  loss_ce_0: 0.6898 (0.7499)  loss_bbox_0: 1.6728 (1.8972)  loss_giou_0: 2.7995 (2.7830)  loss_ce_1: 0.6922 (0.7521)  loss_bbox_1: 1.6745 (1.8838)  loss_giou_1: 2.7742 (2.7949)  loss_ce_2: 0.6902 (0.7529)  loss_bbox_2: 1.6821 (1.8851)  loss_giou_2: 2.7474 (2.7972)  loss_ce_3: 0.6905 (0.7505)  loss_bbox_3: 1.6351 (1.8796)  loss_giou_3: 2.7706 (2.7945)  loss_ce_4: 0.6899 (0.7482)  loss_bbox_4: 1.6249 (1.8865)  loss_giou_4: 2.7661 (2.7930)  loss_ce_unscaled: 0.6921 (0.7429)  class_error_unscaled: 22.2222 (27.2257)  loss_bbox_unscaled: 0.3229 (0.3782)  loss_giou_unscaled: 1.4131 (1.3990)  cardinality_error_unscaled: 223.0000 (200.7391)  loss_mask_unscaled: 0.0182 (0.0217)  loss_dice_unscaled: 0.9637 (0.9672)  loss_ce_0_unscaled: 0.6898 (0.7499)  loss_bbox_0_unscaled: 0.3346 (0.3794)  loss_giou_0_unscaled: 1.3997 (1.3915)  cardinality_error_0_unscaled: 196.0000 (200.2112)  loss_ce_1_unscaled: 0.6922 (0.7521)  loss_bbox_1_unscaled: 0.3349 (0.3768)  loss_giou_1_unscaled: 1.3871 (1.3975)  cardinality_error_1_unscaled: 198.0000 (204.2298)  loss_ce_2_unscaled: 0.6902 (0.7529)  loss_bbox_2_unscaled: 0.3364 (0.3770)  loss_giou_2_unscaled: 1.3737 (1.3986)  cardinality_error_2_unscaled: 205.0000 (202.5342)  loss_ce_3_unscaled: 0.6905 (0.7505)  loss_bbox_3_unscaled: 0.3270 (0.3759)  loss_giou_3_unscaled: 1.3853 (1.3972)  cardinality_error_3_unscaled: 207.0000 (198.8944)  loss_ce_4_unscaled: 0.6899 (0.7482)  loss_bbox_4_unscaled: 0.3250 (0.3773)  loss_giou_4_unscaled: 1.3830 (1.3965)  cardinality_error_4_unscaled: 212.0000 (201.7888)  time: 1.3591  data: 0.0141  max mem: 0
# Epoch: [0]  [  170/23329]  eta: 9:07:59  lr: 0.000100  class_error: 33.33  loss: 33.8606 (33.6356)  loss_ce: 0.6899 (0.7397)  loss_bbox: 1.8500 (1.8946)  loss_giou: 3.0557 (2.8086)  loss_mask: 0.0176 (0.0215)  loss_dice: 0.9580 (0.9666)  loss_ce_0: 0.6903 (0.7465)  loss_bbox_0: 1.8440 (1.8995)  loss_giou_0: 3.0508 (2.7966)  loss_ce_1: 0.6916 (0.7484)  loss_bbox_1: 1.8548 (1.8874)  loss_giou_1: 3.0389 (2.8072)  loss_ce_2: 0.6892 (0.7492)  loss_bbox_2: 1.8085 (1.8886)  loss_giou_2: 3.0600 (2.8085)  loss_ce_3: 0.6893 (0.7468)  loss_bbox_3: 1.8567 (1.8836)  loss_giou_3: 3.0533 (2.8051)  loss_ce_4: 0.6900 (0.7449)  loss_bbox_4: 1.7966 (1.8895)  loss_giou_4: 3.0855 (2.8027)  loss_ce_unscaled: 0.6899 (0.7397)  class_error_unscaled: 25.0000 (27.1118)  loss_bbox_unscaled: 0.3700 (0.3789)  loss_giou_unscaled: 1.5279 (1.4043)  cardinality_error_unscaled: 203.0000 (200.3626)  loss_mask_unscaled: 0.0176 (0.0215)  loss_dice_unscaled: 0.9580 (0.9666)  loss_ce_0_unscaled: 0.6903 (0.7465)  loss_bbox_0_unscaled: 0.3688 (0.3799)  loss_giou_0_unscaled: 1.5254 (1.3983)  cardinality_error_0_unscaled: 205.0000 (200.6023)  loss_ce_1_unscaled: 0.6916 (0.7484)  loss_bbox_1_unscaled: 0.3710 (0.3775)  loss_giou_1_unscaled: 1.5194 (1.4036)  cardinality_error_1_unscaled: 222.0000 (204.6491)  loss_ce_2_unscaled: 0.6892 (0.7492)  loss_bbox_2_unscaled: 0.3617 (0.3777)  loss_giou_2_unscaled: 1.5300 (1.4042)  cardinality_error_2_unscaled: 205.0000 (202.4444)  loss_ce_3_unscaled: 0.6893 (0.7468)  loss_bbox_3_unscaled: 0.3713 (0.3767)  loss_giou_3_unscaled: 1.5266 (1.4025)  cardinality_error_3_unscaled: 204.0000 (199.0234)  loss_ce_4_unscaled: 0.6900 (0.7449)  loss_bbox_4_unscaled: 0.3593 (0.3779)  loss_giou_4_unscaled: 1.5428 (1.4013)  cardinality_error_4_unscaled: 216.0000 (202.0819)  time: 1.3582  data: 0.0142  max mem: 0
# Epoch: [0]  [  180/23329]  eta: 9:06:26  lr: 0.000100  class_error: 11.11  loss: 33.4137 (33.6452)  loss_ce: 0.6884 (0.7369)  loss_bbox: 1.7712 (1.8928)  loss_giou: 3.0018 (2.8150)  loss_mask: 0.0174 (0.0213)  loss_dice: 0.9606 (0.9664)  loss_ce_0: 0.6914 (0.7433)  loss_bbox_0: 1.7039 (1.8949)  loss_giou_0: 2.9769 (2.8029)  loss_ce_1: 0.6912 (0.7451)  loss_bbox_1: 1.7153 (1.8842)  loss_giou_1: 2.9768 (2.8132)  loss_ce_2: 0.6878 (0.7458)  loss_bbox_2: 1.7618 (1.8871)  loss_giou_2: 3.0120 (2.8156)  loss_ce_3: 0.6850 (0.7435)  loss_bbox_3: 1.7638 (1.8827)  loss_giou_3: 2.9963 (2.8125)  loss_ce_4: 0.6894 (0.7417)  loss_bbox_4: 1.7966 (1.8893)  loss_giou_4: 2.9986 (2.8111)  loss_ce_unscaled: 0.6884 (0.7369)  class_error_unscaled: 25.0000 (27.1486)  loss_bbox_unscaled: 0.3542 (0.3786)  loss_giou_unscaled: 1.5009 (1.4075)  cardinality_error_unscaled: 195.0000 (200.2818)  loss_mask_unscaled: 0.0174 (0.0213)  loss_dice_unscaled: 0.9606 (0.9664)  loss_ce_0_unscaled: 0.6914 (0.7433)  loss_bbox_0_unscaled: 0.3408 (0.3790)  loss_giou_0_unscaled: 1.4884 (1.4015)  cardinality_error_0_unscaled: 188.0000 (199.3978)  loss_ce_1_unscaled: 0.6912 (0.7451)  loss_bbox_1_unscaled: 0.3431 (0.3768)  loss_giou_1_unscaled: 1.4884 (1.4066)  cardinality_error_1_unscaled: 208.0000 (204.1934)  loss_ce_2_unscaled: 0.6878 (0.7458)  loss_bbox_2_unscaled: 0.3524 (0.3774)  loss_giou_2_unscaled: 1.5060 (1.4078)  cardinality_error_2_unscaled: 191.0000 (201.6077)  loss_ce_3_unscaled: 0.6850 (0.7435)  loss_bbox_3_unscaled: 0.3528 (0.3765)  loss_giou_3_unscaled: 1.4981 (1.4062)  cardinality_error_3_unscaled: 192.0000 (197.3481)  loss_ce_4_unscaled: 0.6894 (0.7417)  loss_bbox_4_unscaled: 0.3593 (0.3779)  loss_giou_4_unscaled: 1.4993 (1.4056)  cardinality_error_4_unscaled: 186.0000 (201.1657)  time: 1.3588  data: 0.0140  max mem: 0
# Epoch: [0]  [  190/23329]  eta: 9:05:02  lr: 0.000100  class_error: 38.89  loss: 31.2656 (33.4731)  loss_ce: 0.6898 (0.7344)  loss_bbox: 1.6091 (1.8702)  loss_giou: 2.7869 (2.8127)  loss_mask: 0.0167 (0.0211)  loss_dice: 0.9606 (0.9658)  loss_ce_0: 0.6914 (0.7405)  loss_bbox_0: 1.5814 (1.8709)  loss_giou_0: 2.7027 (2.7984)  loss_ce_1: 0.6892 (0.7421)  loss_bbox_1: 1.6049 (1.8610)  loss_giou_1: 2.7229 (2.8085)  loss_ce_2: 0.6891 (0.7428)  loss_bbox_2: 1.6345 (1.8651)  loss_giou_2: 2.7743 (2.8124)  loss_ce_3: 0.6881 (0.7406)  loss_bbox_3: 1.5997 (1.8614)  loss_giou_3: 2.7909 (2.8103)  loss_ce_4: 0.6889 (0.7391)  loss_bbox_4: 1.6373 (1.8671)  loss_giou_4: 2.7751 (2.8086)  loss_ce_unscaled: 0.6898 (0.7344)  class_error_unscaled: 27.7778 (27.0797)  loss_bbox_unscaled: 0.3218 (0.3740)  loss_giou_unscaled: 1.3935 (1.4064)  cardinality_error_unscaled: 197.0000 (200.5969)  loss_mask_unscaled: 0.0167 (0.0211)  loss_dice_unscaled: 0.9606 (0.9658)  loss_ce_0_unscaled: 0.6914 (0.7405)  loss_bbox_0_unscaled: 0.3163 (0.3742)  loss_giou_0_unscaled: 1.3513 (1.3992)  cardinality_error_0_unscaled: 199.0000 (200.4293)  loss_ce_1_unscaled: 0.6892 (0.7421)  loss_bbox_1_unscaled: 0.3210 (0.3722)  loss_giou_1_unscaled: 1.3615 (1.4042)  cardinality_error_1_unscaled: 203.0000 (204.2147)  loss_ce_2_unscaled: 0.6891 (0.7428)  loss_bbox_2_unscaled: 0.3269 (0.3730)  loss_giou_2_unscaled: 1.3872 (1.4062)  cardinality_error_2_unscaled: 199.0000 (202.0157)  loss_ce_3_unscaled: 0.6881 (0.7406)  loss_bbox_3_unscaled: 0.3199 (0.3723)  loss_giou_3_unscaled: 1.3955 (1.4052)  cardinality_error_3_unscaled: 183.0000 (198.2513)  loss_ce_4_unscaled: 0.6889 (0.7391)  loss_bbox_4_unscaled: 0.3275 (0.3734)  loss_giou_4_unscaled: 1.3875 (1.4043)  cardinality_error_4_unscaled: 180.0000 (202.1780)  time: 1.3585  data: 0.0151  max mem: 0
# Epoch: [0]  [  200/23329]  eta: 9:03:42  lr: 0.000100  class_error: 19.44  loss: 29.0781 (33.5009)  loss_ce: 0.6903 (0.7322)  loss_bbox: 1.3252 (1.8741)  loss_giou: 2.7102 (2.8156)  loss_mask: 0.0165 (0.0209)  loss_dice: 0.9610 (0.9657)  loss_ce_0: 0.6914 (0.7381)  loss_bbox_0: 1.2973 (1.8749)  loss_giou_0: 2.6202 (2.8020)  loss_ce_1: 0.6885 (0.7395)  loss_bbox_1: 1.2896 (1.8660)  loss_giou_1: 2.6206 (2.8115)  loss_ce_2: 0.6876 (0.7401)  loss_bbox_2: 1.3298 (1.8695)  loss_giou_2: 2.6850 (2.8151)  loss_ce_3: 0.6903 (0.7382)  loss_bbox_3: 1.3530 (1.8658)  loss_giou_3: 2.7398 (2.8131)  loss_ce_4: 0.6901 (0.7365)  loss_bbox_4: 1.3412 (1.8707)  loss_giou_4: 2.7044 (2.8114)  loss_ce_unscaled: 0.6903 (0.7322)  class_error_unscaled: 19.4445 (26.8795)  loss_bbox_unscaled: 0.2650 (0.3748)  loss_giou_unscaled: 1.3551 (1.4078)  cardinality_error_unscaled: 214.0000 (200.9104)  loss_mask_unscaled: 0.0165 (0.0209)  loss_dice_unscaled: 0.9610 (0.9657)  loss_ce_0_unscaled: 0.6914 (0.7381)  loss_bbox_0_unscaled: 0.2595 (0.3750)  loss_giou_0_unscaled: 1.3101 (1.4010)  cardinality_error_0_unscaled: 215.0000 (200.6119)  loss_ce_1_unscaled: 0.6885 (0.7395)  loss_bbox_1_unscaled: 0.2579 (0.3732)  loss_giou_1_unscaled: 1.3103 (1.4058)  cardinality_error_1_unscaled: 204.0000 (204.3881)  loss_ce_2_unscaled: 0.6876 (0.7401)  loss_bbox_2_unscaled: 0.2660 (0.3739)  loss_giou_2_unscaled: 1.3425 (1.4076)  cardinality_error_2_unscaled: 199.0000 (201.2886)  loss_ce_3_unscaled: 0.6903 (0.7382)  loss_bbox_3_unscaled: 0.2706 (0.3732)  loss_giou_3_unscaled: 1.3699 (1.4065)  cardinality_error_3_unscaled: 212.0000 (198.5622)  loss_ce_4_unscaled: 0.6901 (0.7365)  loss_bbox_4_unscaled: 0.2682 (0.3741)  loss_giou_4_unscaled: 1.3522 (1.4057)  cardinality_error_4_unscaled: 204.0000 (202.1144)  time: 1.3575  data: 0.0148  max mem: 0
# Epoch: [0]  [  210/23329]  eta: 9:02:46  lr: 0.000100  class_error: 25.00  loss: 31.9096 (33.5575)  loss_ce: 0.6893 (0.7301)  loss_bbox: 1.5568 (1.8780)  loss_giou: 2.9336 (2.8235)  loss_mask: 0.0161 (0.0206)  loss_dice: 0.9599 (0.9652)  loss_ce_0: 0.6899 (0.7357)  loss_bbox_0: 1.5399 (1.8788)  loss_giou_0: 2.9111 (2.8106)  loss_ce_1: 0.6876 (0.7370)  loss_bbox_1: 1.5477 (1.8702)  loss_giou_1: 2.9152 (2.8197)  loss_ce_2: 0.6876 (0.7376)  loss_bbox_2: 1.5643 (1.8732)  loss_giou_2: 2.9220 (2.8231)  loss_ce_3: 0.6881 (0.7357)  loss_bbox_3: 1.5726 (1.8698)  loss_giou_3: 2.9282 (2.8211)  loss_ce_4: 0.6870 (0.7342)  loss_bbox_4: 1.5461 (1.8743)  loss_giou_4: 2.9038 (2.8191)  loss_ce_unscaled: 0.6893 (0.7301)  class_error_unscaled: 22.2222 (26.8431)  loss_bbox_unscaled: 0.3114 (0.3756)  loss_giou_unscaled: 1.4668 (1.4117)  cardinality_error_unscaled: 204.0000 (201.0284)  loss_mask_unscaled: 0.0161 (0.0206)  loss_dice_unscaled: 0.9599 (0.9652)  loss_ce_0_unscaled: 0.6899 (0.7357)  loss_bbox_0_unscaled: 0.3080 (0.3758)  loss_giou_0_unscaled: 1.4556 (1.4053)  cardinality_error_0_unscaled: 212.0000 (201.1991)  loss_ce_1_unscaled: 0.6876 (0.7370)  loss_bbox_1_unscaled: 0.3095 (0.3740)  loss_giou_1_unscaled: 1.4576 (1.4099)  cardinality_error_1_unscaled: 204.0000 (204.2464)  loss_ce_2_unscaled: 0.6876 (0.7376)  loss_bbox_2_unscaled: 0.3129 (0.3746)  loss_giou_2_unscaled: 1.4610 (1.4115)  cardinality_error_2_unscaled: 202.0000 (201.8483)  loss_ce_3_unscaled: 0.6881 (0.7357)  loss_bbox_3_unscaled: 0.3145 (0.3740)  loss_giou_3_unscaled: 1.4641 (1.4106)  cardinality_error_3_unscaled: 193.0000 (197.4360)  loss_ce_4_unscaled: 0.6870 (0.7342)  loss_bbox_4_unscaled: 0.3092 (0.3749)  loss_giou_4_unscaled: 1.4519 (1.4095)  cardinality_error_4_unscaled: 200.0000 (202.1896)  time: 1.3641  data: 0.0141  max mem: 0
# Epoch: [0]  [  220/23329]  eta: 9:01:40  lr: 0.000100  class_error: 22.22  loss: 34.6766 (33.6014)  loss_ce: 0.6874 (0.7281)  loss_bbox: 1.7523 (1.8757)  loss_giou: 3.1503 (2.8338)  loss_mask: 0.0153 (0.0204)  loss_dice: 0.9569 (0.9649)  loss_ce_0: 0.6865 (0.7335)  loss_bbox_0: 1.7631 (1.8768)  loss_giou_0: 3.1693 (2.8218)  loss_ce_1: 0.6881 (0.7348)  loss_bbox_1: 1.7583 (1.8693)  loss_giou_1: 3.1654 (2.8307)  loss_ce_2: 0.6878 (0.7354)  loss_bbox_2: 1.7567 (1.8720)  loss_giou_2: 3.1602 (2.8339)  loss_ce_3: 0.6851 (0.7334)  loss_bbox_3: 1.7642 (1.8692)  loss_giou_3: 3.1676 (2.8320)  loss_ce_4: 0.6901 (0.7323)  loss_bbox_4: 1.7965 (1.8733)  loss_giou_4: 3.1826 (2.8301)  loss_ce_unscaled: 0.6874 (0.7281)  class_error_unscaled: 22.2222 (26.6466)  loss_bbox_unscaled: 0.3505 (0.3751)  loss_giou_unscaled: 1.5752 (1.4169)  cardinality_error_unscaled: 205.0000 (201.4977)  loss_mask_unscaled: 0.0153 (0.0204)  loss_dice_unscaled: 0.9569 (0.9649)  loss_ce_0_unscaled: 0.6865 (0.7335)  loss_bbox_0_unscaled: 0.3526 (0.3754)  loss_giou_0_unscaled: 1.5847 (1.4109)  cardinality_error_0_unscaled: 202.0000 (200.7828)  loss_ce_1_unscaled: 0.6881 (0.7348)  loss_bbox_1_unscaled: 0.3517 (0.3739)  loss_giou_1_unscaled: 1.5827 (1.4153)  cardinality_error_1_unscaled: 204.0000 (204.2398)  loss_ce_2_unscaled: 0.6878 (0.7354)  loss_bbox_2_unscaled: 0.3513 (0.3744)  loss_giou_2_unscaled: 1.5801 (1.4169)  cardinality_error_2_unscaled: 197.0000 (201.3846)  loss_ce_3_unscaled: 0.6851 (0.7334)  loss_bbox_3_unscaled: 0.3528 (0.3738)  loss_giou_3_unscaled: 1.5838 (1.4160)  cardinality_error_3_unscaled: 186.0000 (198.0136)  loss_ce_4_unscaled: 0.6901 (0.7323)  loss_bbox_4_unscaled: 0.3593 (0.3747)  loss_giou_4_unscaled: 1.5913 (1.4151)  cardinality_error_4_unscaled: 199.0000 (202.7647)  time: 1.3656  data: 0.0153  max mem: 0
# Epoch: [0]  [  230/23329]  eta: 9:00:35  lr: 0.000100  class_error: 22.22  loss: 35.9122 (33.5773)  loss_ce: 0.6853 (0.7264)  loss_bbox: 1.9330 (1.8732)  loss_giou: 3.2145 (2.8336)  loss_mask: 0.0149 (0.0202)  loss_dice: 0.9578 (0.9645)  loss_ce_0: 0.6887 (0.7316)  loss_bbox_0: 1.9350 (1.8748)  loss_giou_0: 3.2269 (2.8222)  loss_ce_1: 0.6893 (0.7329)  loss_bbox_1: 1.9173 (1.8675)  loss_giou_1: 3.2144 (2.8303)  loss_ce_2: 0.6883 (0.7334)  loss_bbox_2: 1.9094 (1.8701)  loss_giou_2: 3.2169 (2.8336)  loss_ce_3: 0.6883 (0.7315)  loss_bbox_3: 1.8765 (1.8675)  loss_giou_3: 3.2018 (2.8320)  loss_ce_4: 0.6913 (0.7305)  loss_bbox_4: 1.8957 (1.8716)  loss_giou_4: 3.2149 (2.8299)  loss_ce_unscaled: 0.6853 (0.7264)  class_error_unscaled: 22.2222 (26.4671)  loss_bbox_unscaled: 0.3866 (0.3746)  loss_giou_unscaled: 1.6072 (1.4168)  cardinality_error_unscaled: 208.0000 (201.8052)  loss_mask_unscaled: 0.0149 (0.0202)  loss_dice_unscaled: 0.9578 (0.9645)  loss_ce_0_unscaled: 0.6887 (0.7316)  loss_bbox_0_unscaled: 0.3870 (0.3750)  loss_giou_0_unscaled: 1.6134 (1.4111)  cardinality_error_0_unscaled: 201.0000 (201.1602)  loss_ce_1_unscaled: 0.6893 (0.7329)  loss_bbox_1_unscaled: 0.3835 (0.3735)  loss_giou_1_unscaled: 1.6072 (1.4152)  cardinality_error_1_unscaled: 200.0000 (203.8355)  loss_ce_2_unscaled: 0.6883 (0.7334)  loss_bbox_2_unscaled: 0.3819 (0.3740)  loss_giou_2_unscaled: 1.6084 (1.4168)  cardinality_error_2_unscaled: 192.0000 (201.2944)  loss_ce_3_unscaled: 0.6883 (0.7315)  loss_bbox_3_unscaled: 0.3753 (0.3735)  loss_giou_3_unscaled: 1.6009 (1.4160)  cardinality_error_3_unscaled: 197.0000 (197.8831)  loss_ce_4_unscaled: 0.6913 (0.7305)  loss_bbox_4_unscaled: 0.3791 (0.3743)  loss_giou_4_unscaled: 1.6074 (1.4150)  cardinality_error_4_unscaled: 199.0000 (202.6580)  time: 1.3573  data: 0.0147  max mem: 0
# Epoch: [0]  [  240/23329]  eta: 8:59:38  lr: 0.000100  class_error: 33.33  loss: 35.6166 (33.4880)  loss_ce: 0.6891 (0.7248)  loss_bbox: 1.8980 (1.8647)  loss_giou: 3.1270 (2.8288)  loss_mask: 0.0146 (0.0200)  loss_dice: 0.9552 (0.9642)  loss_ce_0: 0.6887 (0.7298)  loss_bbox_0: 1.8819 (1.8658)  loss_giou_0: 3.1177 (2.8178)  loss_ce_1: 0.6879 (0.7310)  loss_bbox_1: 1.9044 (1.8597)  loss_giou_1: 3.1365 (2.8258)  loss_ce_2: 0.6868 (0.7314)  loss_bbox_2: 1.9121 (1.8623)  loss_giou_2: 3.1343 (2.8289)  loss_ce_3: 0.6883 (0.7296)  loss_bbox_3: 1.8626 (1.8590)  loss_giou_3: 3.1131 (2.8271)  loss_ce_4: 0.6911 (0.7288)  loss_bbox_4: 1.8860 (1.8634)  loss_giou_4: 3.1108 (2.8249)  loss_ce_unscaled: 0.6891 (0.7248)  class_error_unscaled: 25.0000 (26.5675)  loss_bbox_unscaled: 0.3796 (0.3729)  loss_giou_unscaled: 1.5635 (1.4144)  cardinality_error_unscaled: 208.0000 (201.7178)  loss_mask_unscaled: 0.0146 (0.0200)  loss_dice_unscaled: 0.9552 (0.9642)  loss_ce_0_unscaled: 0.6887 (0.7298)  loss_bbox_0_unscaled: 0.3764 (0.3732)  loss_giou_0_unscaled: 1.5588 (1.4089)  cardinality_error_0_unscaled: 199.0000 (200.7967)  loss_ce_1_unscaled: 0.6879 (0.7310)  loss_bbox_1_unscaled: 0.3809 (0.3719)  loss_giou_1_unscaled: 1.5682 (1.4129)  cardinality_error_1_unscaled: 203.0000 (204.6058)  loss_ce_2_unscaled: 0.6868 (0.7314)  loss_bbox_2_unscaled: 0.3824 (0.3725)  loss_giou_2_unscaled: 1.5672 (1.4144)  cardinality_error_2_unscaled: 202.0000 (201.5353)  loss_ce_3_unscaled: 0.6883 (0.7296)  loss_bbox_3_unscaled: 0.3725 (0.3718)  loss_giou_3_unscaled: 1.5566 (1.4136)  cardinality_error_3_unscaled: 197.0000 (198.4730)  loss_ce_4_unscaled: 0.6911 (0.7288)  loss_bbox_4_unscaled: 0.3772 (0.3727)  loss_giou_4_unscaled: 1.5554 (1.4124)  cardinality_error_4_unscaled: 206.0000 (203.2033)  time: 1.3576  data: 0.0154  max mem: 0
# Epoch: [0]  [  250/23329]  eta: 8:58:40  lr: 0.000100  class_error: 22.22  loss: 35.1676 (33.5500)  loss_ce: 0.6888 (0.7233)  loss_bbox: 1.8857 (1.8689)  loss_giou: 2.9525 (2.8364)  loss_mask: 0.0153 (0.0198)  loss_dice: 0.9577 (0.9640)  loss_ce_0: 0.6863 (0.7281)  loss_bbox_0: 1.8479 (1.8694)  loss_giou_0: 2.9563 (2.8265)  loss_ce_1: 0.6868 (0.7292)  loss_bbox_1: 1.8769 (1.8636)  loss_giou_1: 2.9759 (2.8341)  loss_ce_2: 0.6856 (0.7296)  loss_bbox_2: 1.9042 (1.8666)  loss_giou_2: 2.9633 (2.8367)  loss_ce_3: 0.6856 (0.7278)  loss_bbox_3: 1.8448 (1.8634)  loss_giou_3: 2.9526 (2.8351)  loss_ce_4: 0.6866 (0.7271)  loss_bbox_4: 1.8654 (1.8675)  loss_giou_4: 2.9524 (2.8328)  loss_ce_unscaled: 0.6888 (0.7233)  class_error_unscaled: 25.0000 (26.4387)  loss_bbox_unscaled: 0.3771 (0.3738)  loss_giou_unscaled: 1.4763 (1.4182)  cardinality_error_unscaled: 207.0000 (202.0797)  loss_mask_unscaled: 0.0153 (0.0198)  loss_dice_unscaled: 0.9577 (0.9640)  loss_ce_0_unscaled: 0.6863 (0.7281)  loss_bbox_0_unscaled: 0.3696 (0.3739)  loss_giou_0_unscaled: 1.4781 (1.4132)  cardinality_error_0_unscaled: 199.0000 (201.1474)  loss_ce_1_unscaled: 0.6868 (0.7292)  loss_bbox_1_unscaled: 0.3754 (0.3727)  loss_giou_1_unscaled: 1.4880 (1.4170)  cardinality_error_1_unscaled: 199.0000 (204.1036)  loss_ce_2_unscaled: 0.6856 (0.7296)  loss_bbox_2_unscaled: 0.3808 (0.3733)  loss_giou_2_unscaled: 1.4816 (1.4184)  cardinality_error_2_unscaled: 202.0000 (201.3944)  loss_ce_3_unscaled: 0.6856 (0.7278)  loss_bbox_3_unscaled: 0.3690 (0.3727)  loss_giou_3_unscaled: 1.4763 (1.4176)  cardinality_error_3_unscaled: 212.0000 (198.4143)  loss_ce_4_unscaled: 0.6866 (0.7271)  loss_bbox_4_unscaled: 0.3731 (0.3735)  loss_giou_4_unscaled: 1.4762 (1.4164)  cardinality_error_4_unscaled: 209.0000 (202.8566)  time: 1.3570  data: 0.0166  max mem: 0
# ...
# Epoch: [0]  [16090/23329]  eta: 2:43:00  lr: 0.000100  class_error: 19.44  loss: 35.5728 (31.6897)  loss_ce: 0.6823 (0.6826)  loss_bbox: 1.9480 (1.7161)  loss_giou: 3.1879 (2.8273)  loss_mask: 0.0070 (0.0057)  loss_dice: 0.1153 (0.3265)  loss_ce_0: 0.6838 (0.6827)  loss_bbox_0: 1.9494 (1.7167)  loss_giou_0: 3.1848 (2.8269)  loss_ce_1: 0.6819 (0.6827)  loss_bbox_1: 1.9474 (1.7163)  loss_giou_1: 3.1877 (2.8269)  loss_ce_2: 0.6805 (0.6827)  loss_bbox_2: 1.9419 (1.7162)  loss_giou_2: 3.1883 (2.8270)  loss_ce_3: 0.6808 (0.6828)  loss_bbox_3: 1.9440 (1.7165)  loss_giou_3: 3.1820 (2.8270)  loss_ce_4: 0.6827 (0.6827)  loss_bbox_4: 1.9391 (1.7173)  loss_giou_4: 3.1858 (2.8271)  loss_ce_unscaled: 0.6823 (0.6826)  class_error_unscaled: 25.0000 (28.6958)  loss_bbox_unscaled: 0.3896 (0.3432)  loss_giou_unscaled: 1.5940 (1.4136)  cardinality_error_unscaled: 192.0000 (186.8891)  loss_mask_unscaled: 0.0070 (0.0057)  loss_dice_unscaled: 0.1153 (0.3265)  loss_ce_0_unscaled: 0.6838 (0.6827)  loss_bbox_0_unscaled: 0.3899 (0.3433)  loss_giou_0_unscaled: 1.5924 (1.4134)  cardinality_error_0_unscaled: 190.0000 (186.3822)  loss_ce_1_unscaled: 0.6819 (0.6827)  loss_bbox_1_unscaled: 0.3895 (0.3433)  loss_giou_1_unscaled: 1.5939 (1.4134)  cardinality_error_1_unscaled: 185.0000 (185.5444)  loss_ce_2_unscaled: 0.6805 (0.6827)  loss_bbox_2_unscaled: 0.3884 (0.3432)  loss_giou_2_unscaled: 1.5942 (1.4135)  cardinality_error_2_unscaled: 195.0000 (187.9267)  loss_ce_3_unscaled: 0.6808 (0.6828)  loss_bbox_3_unscaled: 0.3888 (0.3433)  loss_giou_3_unscaled: 1.5910 (1.4135)  cardinality_error_3_unscaled: 169.0000 (182.4173)  loss_ce_4_unscaled: 0.6827 (0.6827)  loss_bbox_4_unscaled: 0.3878 (0.3435)  loss_giou_4_unscaled: 1.5929 (1.4136)  cardinality_error_4_unscaled: 188.0000 (183.4094)  time: 1.3512  data: 0.0148  max mem: 0
# Epoch: [0]  [16100/23329]  eta: 2:42:47  lr: 0.000100  class_error: 41.67  loss: 32.6297 (31.6892)  loss_ce: 0.6823 (0.6826)  loss_bbox: 1.6279 (1.7160)  loss_giou: 3.1062 (2.8273)  loss_mask: 0.0063 (0.0057)  loss_dice: 0.1153 (0.3264)  loss_ce_0: 0.6811 (0.6827)  loss_bbox_0: 1.6313 (1.7167)  loss_giou_0: 3.1102 (2.8269)  loss_ce_1: 0.6806 (0.6827)  loss_bbox_1: 1.6243 (1.7163)  loss_giou_1: 3.1113 (2.8269)  loss_ce_2: 0.6837 (0.6827)  loss_bbox_2: 1.6353 (1.7161)  loss_giou_2: 3.1066 (2.8270)  loss_ce_3: 0.6817 (0.6828)  loss_bbox_3: 1.6282 (1.7164)  loss_giou_3: 3.1076 (2.8270)  loss_ce_4: 0.6836 (0.6827)  loss_bbox_4: 1.6313 (1.7172)  loss_giou_4: 3.1100 (2.8271)  loss_ce_unscaled: 0.6823 (0.6826)  class_error_unscaled: 27.7778 (28.6956)  loss_bbox_unscaled: 0.3256 (0.3432)  loss_giou_unscaled: 1.5531 (1.4136)  cardinality_error_unscaled: 184.0000 (186.8886)  loss_mask_unscaled: 0.0063 (0.0057)  loss_dice_unscaled: 0.1153 (0.3264)  loss_ce_0_unscaled: 0.6811 (0.6827)  loss_bbox_0_unscaled: 0.3263 (0.3433)  loss_giou_0_unscaled: 1.5551 (1.4134)  cardinality_error_0_unscaled: 192.0000 (186.3829)  loss_ce_1_unscaled: 0.6806 (0.6827)  loss_bbox_1_unscaled: 0.3249 (0.3433)  loss_giou_1_unscaled: 1.5557 (1.4134)  cardinality_error_1_unscaled: 184.0000 (185.5518)  loss_ce_2_unscaled: 0.6837 (0.6827)  loss_bbox_2_unscaled: 0.3271 (0.3432)  loss_giou_2_unscaled: 1.5533 (1.4135)  cardinality_error_2_unscaled: 195.0000 (187.9344)  loss_ce_3_unscaled: 0.6817 (0.6828)  loss_bbox_3_unscaled: 0.3256 (0.3433)  loss_giou_3_unscaled: 1.5538 (1.4135)  cardinality_error_3_unscaled: 183.0000 (182.4128)  loss_ce_4_unscaled: 0.6836 (0.6827)  loss_bbox_4_unscaled: 0.3263 (0.3434)  loss_giou_4_unscaled: 1.5550 (1.4136)  cardinality_error_4_unscaled: 184.0000 (183.4104)  time: 1.3488  data: 0.0133  max mem: 0
# Epoch: [0]  [16110/23329]  eta: 2:42:33  lr: 0.000100  class_error: 11.11  loss: 31.1522 (31.6867)  loss_ce: 0.6808 (0.6826)  loss_bbox: 1.4867 (1.7158)  loss_giou: 2.9397 (2.8271)  loss_mask: 0.0053 (0.0057)  loss_dice: 0.1097 (0.3263)  loss_ce_0: 0.6811 (0.6827)  loss_bbox_0: 1.4794 (1.7164)  loss_giou_0: 2.9452 (2.8267)  loss_ce_1: 0.6848 (0.6827)  loss_bbox_1: 1.4820 (1.7160)  loss_giou_1: 2.9492 (2.8267)  loss_ce_2: 0.6848 (0.6827)  loss_bbox_2: 1.4834 (1.7159)  loss_giou_2: 2.9407 (2.8268)  loss_ce_3: 0.6817 (0.6828)  loss_bbox_3: 1.4827 (1.7162)  loss_giou_3: 2.9484 (2.8268)  loss_ce_4: 0.6836 (0.6827)  loss_bbox_4: 1.4943 (1.7170)  loss_giou_4: 2.9412 (2.8269)  loss_ce_unscaled: 0.6808 (0.6826)  class_error_unscaled: 25.0000 (28.6933)  loss_bbox_unscaled: 0.2973 (0.3432)  loss_giou_unscaled: 1.4699 (1.4135)  cardinality_error_unscaled: 194.0000 (186.8970)  loss_mask_unscaled: 0.0053 (0.0057)  loss_dice_unscaled: 0.1097 (0.3263)  loss_ce_0_unscaled: 0.6811 (0.6827)  loss_bbox_0_unscaled: 0.2959 (0.3433)  loss_giou_0_unscaled: 1.4726 (1.4133)  cardinality_error_0_unscaled: 188.0000 (186.3851)  loss_ce_1_unscaled: 0.6848 (0.6827)  loss_bbox_1_unscaled: 0.2964 (0.3432)  loss_giou_1_unscaled: 1.4746 (1.4133)  cardinality_error_1_unscaled: 196.0000 (185.5579)  loss_ce_2_unscaled: 0.6848 (0.6827)  loss_bbox_2_unscaled: 0.2967 (0.3432)  loss_giou_2_unscaled: 1.4703 (1.4134)  cardinality_error_2_unscaled: 192.0000 (187.9350)  loss_ce_3_unscaled: 0.6817 (0.6828)  loss_bbox_3_unscaled: 0.2965 (0.3432)  loss_giou_3_unscaled: 1.4742 (1.4134)  cardinality_error_3_unscaled: 175.0000 (182.4125)  loss_ce_4_unscaled: 0.6836 (0.6827)  loss_bbox_4_unscaled: 0.2989 (0.3434)  loss_giou_4_unscaled: 1.4706 (1.4135)  cardinality_error_4_unscaled: 182.0000 (183.4120)  time: 1.3506  data: 0.0132  max mem: 0
# Epoch: [0]  [16120/23329]  eta: 2:42:20  lr: 0.000100  class_error: 33.33  loss: 29.7283 (31.6864)  loss_ce: 0.6838 (0.6826)  loss_bbox: 1.3705 (1.7158)  loss_giou: 2.8329 (2.8271)  loss_mask: 0.0046 (0.0057)  loss_dice: 0.0993 (0.3261)  loss_ce_0: 0.6806 (0.6827)  loss_bbox_0: 1.3884 (1.7164)  loss_giou_0: 2.8211 (2.8267)  loss_ce_1: 0.6848 (0.6827)  loss_bbox_1: 1.3790 (1.7160)  loss_giou_1: 2.8308 (2.8267)  loss_ce_2: 0.6844 (0.6827)  loss_bbox_2: 1.3745 (1.7158)  loss_giou_2: 2.8246 (2.8269)  loss_ce_3: 0.6813 (0.6828)  loss_bbox_3: 1.3696 (1.7161)  loss_giou_3: 2.8338 (2.8268)  loss_ce_4: 0.6804 (0.6827)  loss_bbox_4: 1.3894 (1.7170)  loss_giou_4: 2.8329 (2.8270)  loss_ce_unscaled: 0.6838 (0.6826)  class_error_unscaled: 27.7778 (28.6951)  loss_bbox_unscaled: 0.2741 (0.3432)  loss_giou_unscaled: 1.4165 (1.4136)  cardinality_error_unscaled: 192.0000 (186.8927)  loss_mask_unscaled: 0.0046 (0.0057)  loss_dice_unscaled: 0.0993 (0.3261)  loss_ce_0_unscaled: 0.6806 (0.6827)  loss_bbox_0_unscaled: 0.2777 (0.3433)  loss_giou_0_unscaled: 1.4105 (1.4134)  cardinality_error_0_unscaled: 188.0000 (186.3885)  loss_ce_1_unscaled: 0.6848 (0.6827)  loss_bbox_1_unscaled: 0.2758 (0.3432)  loss_giou_1_unscaled: 1.4154 (1.4134)  cardinality_error_1_unscaled: 186.0000 (185.5552)  loss_ce_2_unscaled: 0.6844 (0.6827)  loss_bbox_2_unscaled: 0.2749 (0.3432)  loss_giou_2_unscaled: 1.4123 (1.4134)  cardinality_error_2_unscaled: 193.0000 (187.9440)  loss_ce_3_unscaled: 0.6813 (0.6828)  loss_bbox_3_unscaled: 0.2739 (0.3432)  loss_giou_3_unscaled: 1.4169 (1.4134)  cardinality_error_3_unscaled: 181.0000 (182.4139)  loss_ce_4_unscaled: 0.6804 (0.6827)  loss_bbox_4_unscaled: 0.2779 (0.3434)  loss_giou_4_unscaled: 1.4164 (1.4135)  cardinality_error_4_unscaled: 179.0000 (183.4086)  time: 1.3518  data: 0.0131  max mem: 0
# Epoch: [0]  [16130/23329]  eta: 2:42:06  lr: 0.000100  class_error: 41.67  loss: 29.8071 (31.6857)  loss_ce: 0.6811 (0.6826)  loss_bbox: 1.4400 (1.7156)  loss_giou: 2.8480 (2.8271)  loss_mask: 0.0046 (0.0057)  loss_dice: 0.1001 (0.3260)  loss_ce_0: 0.6771 (0.6827)  loss_bbox_0: 1.4355 (1.7163)  loss_giou_0: 2.8474 (2.8267)  loss_ce_1: 0.6822 (0.6827)  loss_bbox_1: 1.4323 (1.7159)  loss_giou_1: 2.8497 (2.8267)  loss_ce_2: 0.6842 (0.6827)  loss_bbox_2: 1.4460 (1.7157)  loss_giou_2: 2.8468 (2.8269)  loss_ce_3: 0.6844 (0.6828)  loss_bbox_3: 1.4473 (1.7160)  loss_giou_3: 2.8533 (2.8268)  loss_ce_4: 0.6793 (0.6827)  loss_bbox_4: 1.4360 (1.7168)  loss_giou_4: 2.8550 (2.8270)  loss_ce_unscaled: 0.6811 (0.6826)  class_error_unscaled: 27.7778 (28.6946)  loss_bbox_unscaled: 0.2880 (0.3431)  loss_giou_unscaled: 1.4240 (1.4136)  cardinality_error_unscaled: 184.0000 (186.8955)  loss_mask_unscaled: 0.0046 (0.0057)  loss_dice_unscaled: 0.1001 (0.3260)  loss_ce_0_unscaled: 0.6771 (0.6827)  loss_bbox_0_unscaled: 0.2871 (0.3433)  loss_giou_0_unscaled: 1.4237 (1.4134)  cardinality_error_0_unscaled: 187.0000 (186.3878)  loss_ce_1_unscaled: 0.6822 (0.6827)  loss_bbox_1_unscaled: 0.2865 (0.3432)  loss_giou_1_unscaled: 1.4248 (1.4134)  cardinality_error_1_unscaled: 183.0000 (185.5559)  loss_ce_2_unscaled: 0.6842 (0.6827)  loss_bbox_2_unscaled: 0.2892 (0.3431)  loss_giou_2_unscaled: 1.4234 (1.4134)  cardinality_error_2_unscaled: 197.0000 (187.9484)  loss_ce_3_unscaled: 0.6844 (0.6828)  loss_bbox_3_unscaled: 0.2895 (0.3432)  loss_giou_3_unscaled: 1.4267 (1.4134)  cardinality_error_3_unscaled: 184.0000 (182.4149)  loss_ce_4_unscaled: 0.6793 (0.6827)  loss_bbox_4_unscaled: 0.2872 (0.3434)  loss_giou_4_unscaled: 1.4275 (1.4135)  cardinality_error_4_unscaled: 178.0000 (183.4084)  time: 1.3519  data: 0.0137  max mem: 0
# Epoch: [0]  [16140/23329]  eta: 2:41:53  lr: 0.000100  class_error: 19.44  loss: 31.7714 (31.6876)  loss_ce: 0.6808 (0.6826)  loss_bbox: 1.6358 (1.7159)  loss_giou: 2.9745 (2.8272)  loss_mask: 0.0057 (0.0057)  loss_dice: 0.1200 (0.3259)  loss_ce_0: 0.6776 (0.6827)  loss_bbox_0: 1.6672 (1.7165)  loss_giou_0: 2.9984 (2.8268)  loss_ce_1: 0.6806 (0.6827)  loss_bbox_1: 1.6554 (1.7161)  loss_giou_1: 2.9768 (2.8268)  loss_ce_2: 0.6828 (0.6827)  loss_bbox_2: 1.6398 (1.7160)  loss_giou_2: 2.9691 (2.8270)  loss_ce_3: 0.6857 (0.6828)  loss_bbox_3: 1.6453 (1.7163)  loss_giou_3: 2.9684 (2.8269)  loss_ce_4: 0.6791 (0.6827)  loss_bbox_4: 1.6617 (1.7171)  loss_giou_4: 2.9698 (2.8271)  loss_ce_unscaled: 0.6808 (0.6826)  class_error_unscaled: 22.2222 (28.6916)  loss_bbox_unscaled: 0.3272 (0.3432)  loss_giou_unscaled: 1.4872 (1.4136)  cardinality_error_unscaled: 204.0000 (186.9032)  loss_mask_unscaled: 0.0057 (0.0057)  loss_dice_unscaled: 0.1200 (0.3259)  loss_ce_0_unscaled: 0.6776 (0.6827)  loss_bbox_0_unscaled: 0.3334 (0.3433)  loss_giou_0_unscaled: 1.4992 (1.4134)  cardinality_error_0_unscaled: 187.0000 (186.3914)  loss_ce_1_unscaled: 0.6806 (0.6827)  loss_bbox_1_unscaled: 0.3311 (0.3432)  loss_giou_1_unscaled: 1.4884 (1.4134)  cardinality_error_1_unscaled: 184.0000 (185.5575)  loss_ce_2_unscaled: 0.6828 (0.6827)  loss_bbox_2_unscaled: 0.3280 (0.3432)  loss_giou_2_unscaled: 1.4846 (1.4135)  cardinality_error_2_unscaled: 198.0000 (187.9597)  loss_ce_3_unscaled: 0.6857 (0.6828)  loss_bbox_3_unscaled: 0.3291 (0.3433)  loss_giou_3_unscaled: 1.4842 (1.4135)  cardinality_error_3_unscaled: 180.0000 (182.4129)  loss_ce_4_unscaled: 0.6791 (0.6827)  loss_bbox_4_unscaled: 0.3323 (0.3434)  loss_giou_4_unscaled: 1.4849 (1.4135)  cardinality_error_4_unscaled: 181.0000 (183.4104)  time: 1.3511  data: 0.0146  max mem: 0
# Epoch: [0]  [16150/23329]  eta: 2:41:39  lr: 0.000100  class_error: 38.89  loss: 32.3859 (31.6865)  loss_ce: 0.6816 (0.6826)  loss_bbox: 1.7556 (1.7158)  loss_giou: 2.9745 (2.8271)  loss_mask: 0.0059 (0.0058)  loss_dice: 0.1204 (0.3257)  loss_ce_0: 0.6799 (0.6827)  loss_bbox_0: 1.7788 (1.7165)  loss_giou_0: 2.9984 (2.8267)  loss_ce_1: 0.6817 (0.6827)  loss_bbox_1: 1.7616 (1.7161)  loss_giou_1: 2.9768 (2.8267)  loss_ce_2: 0.6804 (0.6827)  loss_bbox_2: 1.7560 (1.7159)  loss_giou_2: 2.9691 (2.8269)  loss_ce_3: 0.6821 (0.6828)  loss_bbox_3: 1.7598 (1.7162)  loss_giou_3: 2.9684 (2.8268)  loss_ce_4: 0.6786 (0.6827)  loss_bbox_4: 1.7686 (1.7170)  loss_giou_4: 2.9698 (2.8270)  loss_ce_unscaled: 0.6816 (0.6826)  class_error_unscaled: 27.7778 (28.6945)  loss_bbox_unscaled: 0.3511 (0.3432)  loss_giou_unscaled: 1.4872 (1.4136)  cardinality_error_unscaled: 174.0000 (186.8925)  loss_mask_unscaled: 0.0059 (0.0058)  loss_dice_unscaled: 0.1204 (0.3257)  loss_ce_0_unscaled: 0.6799 (0.6827)  loss_bbox_0_unscaled: 0.3558 (0.3433)  loss_giou_0_unscaled: 1.4992 (1.4134)  cardinality_error_0_unscaled: 191.0000 (186.3930)  loss_ce_1_unscaled: 0.6817 (0.6827)  loss_bbox_1_unscaled: 0.3523 (0.3432)  loss_giou_1_unscaled: 1.4884 (1.4134)  cardinality_error_1_unscaled: 186.0000 (185.5637)  loss_ce_2_unscaled: 0.6804 (0.6827)  loss_bbox_2_unscaled: 0.3512 (0.3432)  loss_giou_2_unscaled: 1.4846 (1.4134)  cardinality_error_2_unscaled: 201.0000 (187.9656)  loss_ce_3_unscaled: 0.6821 (0.6828)  loss_bbox_3_unscaled: 0.3520 (0.3432)  loss_giou_3_unscaled: 1.4842 (1.4134)  cardinality_error_3_unscaled: 175.0000 (182.4149)  loss_ce_4_unscaled: 0.6786 (0.6827)  loss_bbox_4_unscaled: 0.3537 (0.3434)  loss_giou_4_unscaled: 1.4849 (1.4135)  cardinality_error_4_unscaled: 187.0000 (183.4115)  time: 1.3521  data: 0.0142  max mem: 0
# Epoch: [0]  [16160/23329]  eta: 2:41:25  lr: 0.000100  class_error: 22.22  loss: 32.8315 (31.6885)  loss_ce: 0.6806 (0.6826)  loss_bbox: 1.8018 (1.7160)  loss_giou: 3.0116 (2.8273)  loss_mask: 0.0047 (0.0057)  loss_dice: 0.0990 (0.3256)  loss_ce_0: 0.6848 (0.6827)  loss_bbox_0: 1.7930 (1.7167)  loss_giou_0: 3.0231 (2.8269)  loss_ce_1: 0.6846 (0.6827)  loss_bbox_1: 1.7979 (1.7163)  loss_giou_1: 3.0149 (2.8269)  loss_ce_2: 0.6787 (0.6827)  loss_bbox_2: 1.7995 (1.7161)  loss_giou_2: 3.0128 (2.8270)  loss_ce_3: 0.6818 (0.6828)  loss_bbox_3: 1.7983 (1.7164)  loss_giou_3: 3.0132 (2.8270)  loss_ce_4: 0.6812 (0.6827)  loss_bbox_4: 1.7938 (1.7172)  loss_giou_4: 3.0153 (2.8271)  loss_ce_unscaled: 0.6806 (0.6826)  class_error_unscaled: 30.5556 (28.6925)  loss_bbox_unscaled: 0.3604 (0.3432)  loss_giou_unscaled: 1.5058 (1.4136)  cardinality_error_unscaled: 174.0000 (186.8938)  loss_mask_unscaled: 0.0047 (0.0057)  loss_dice_unscaled: 0.0990 (0.3256)  loss_ce_0_unscaled: 0.6848 (0.6827)  loss_bbox_0_unscaled: 0.3586 (0.3433)  loss_giou_0_unscaled: 1.5115 (1.4134)  cardinality_error_0_unscaled: 191.0000 (186.3937)  loss_ce_1_unscaled: 0.6846 (0.6827)  loss_bbox_1_unscaled: 0.3596 (0.3433)  loss_giou_1_unscaled: 1.5075 (1.4134)  cardinality_error_1_unscaled: 186.0000 (185.5612)  loss_ce_2_unscaled: 0.6787 (0.6827)  loss_bbox_2_unscaled: 0.3599 (0.3432)  loss_giou_2_unscaled: 1.5064 (1.4135)  cardinality_error_2_unscaled: 192.0000 (187.9664)  loss_ce_3_unscaled: 0.6818 (0.6828)  loss_bbox_3_unscaled: 0.3597 (0.3433)  loss_giou_3_unscaled: 1.5066 (1.4135)  cardinality_error_3_unscaled: 187.0000 (182.4179)  loss_ce_4_unscaled: 0.6812 (0.6827)  loss_bbox_4_unscaled: 0.3588 (0.3434)  loss_giou_4_unscaled: 1.5076 (1.4136)  cardinality_error_4_unscaled: 182.0000 (183.4099)  time: 1.3523  data: 0.0134  max mem: 0
